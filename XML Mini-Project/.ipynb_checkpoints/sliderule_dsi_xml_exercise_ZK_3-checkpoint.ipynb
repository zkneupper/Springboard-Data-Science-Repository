# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
#    print child.find('name').text
    print(child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print( '* ' + element.find('name').text + ':',)
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print( capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %% [markdown]
# # FROM THIS CELL ONWARDS IS MINE

# %% [markdown]
# First, import necessary libraries.

# %%
import sys
from lxml import etree
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# Read in data using the lxml parser function.

# %%
document = etree.parse('./data/mondial_database.xml' )

# %% [markdown]
# Preview the document.

# %%
document

# %%
type(document)
# Out:
# lxml.etree._ElementTree

# %%
len(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode())
# Out:
# 3169173

# %% [markdown]
# Print the first ten thousand characters of the document to see what it looks like.

# %%
print(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode()[0:10000])
# Out:
# <!DOCTYPE mondial SYSTEM "mondial.dtd">
# <mondial>
#    <country car_code="AL" area="28750" capital="cty-Albania-Tirane" memberships="org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO">
#       <name>Albania</name>
#       <population measured="est." year="1950">1214489</population>
#       <population measured="est." year="1960">1618829</population>
#       <population measured="est." year="1970">2138966</population>
#       <population measured="est." year="1980">2734776</population>
#       <population measured="est." year="1990">3446882</population>
#       <population year="1997">3249136</population>
#       <population measured="est." year="2000">3304948</population>
#       <population year="2001" measured="census">3069275</population>
#       <population year="2011" measured="census">2800138</population>
#       <population_growth>0.3</population_growth>
#       <infant_mortality>13.19</infant_mortality>
#       <gdp_total>12800</gdp_total>
#       <gdp_agri>19.5</gdp_agri>
#       <gdp_ind>12</gdp_ind>
#       <gdp_serv>68.5</gdp_serv>
#       <inflation>1.7</inflation>
#       <unemployment>16.9</unemployment>
#       <indep_date from="Ottoman Empire">1912-11-28</indep_date>
#       <government>parliamentary democracy</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="95">Albanian</ethnicgroup>
#       <ethnicgroup percentage="3">Greek</ethnicgroup>
#       <religion percentage="70">Muslim</religion>
#       <religion percentage="10">Roman Catholic</religion>
#       <religion percentage="20">Christian Orthodox</religion>
#       <language percentage="98.8">Albanian</language>
#       <language percentage="0.5">Greek</language>
#       <border country="GR" length="282"/>
#       <border country="MK" length="151"/>
#       <border country="MNE" length="172"/>
#       <border country="KOS" length="112"/>
#       <city id="cty-Albania-Tirane" country="AL">
#          <name>Tirana</name>
#          <name>Tirane</name>
#          <latitude>41.3</latitude>
#          <longitude>19.8</longitude>
#          <population year="1987">192000</population>
#          <population year="1990" measured="estimate">244153</population>
#          <population year="2011" measured="census">418495</population>
#       </city>
#       <city id="stadt-Shkoder-AL-AL" country="AL">
#          <name>Shkodër</name>
#          <latitude>42.2</latitude>
#          <longitude>19.2</longitude>
#          <population year="1987">62000</population>
#          <population year="2011" measured="census">77075</population>
#          <located_at watertype="lake" lake="lake-Skutarisee"/>
#       </city>
#       <city id="stadt-Durres-AL-AL" country="AL">
#          <name>Durrës</name>
#          <latitude>41.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">60000</population>
#          <population year="2011" measured="census">113249</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Vlore-AL-AL" country="AL">
#          <name>Vlorë</name>
#          <latitude>40.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">56000</population>
#          <population year="2011" measured="census">79513</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Elbasan-AL-AL" country="AL">
#          <name>Elbasan</name>
#          <latitude>41.1</latitude>
#          <longitude>20.1</longitude>
#          <population year="1987">53000</population>
#          <population year="2011" measured="census">78703</population>
#       </city>
#       <city id="stadt-Korce-AL-AL" country="AL">
#          <name>Korçë</name>
#          <latitude>40.4</latitude>
#          <longitude>20.5</longitude>
#          <population year="1987">52000</population>
#          <population year="2011" measured="census">51152</population>
#       </city>
#    </country>
#    <country car_code="GR" area="131940" capital="cty-Greece-Athens" memberships="org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC">
#       <name>Greece</name>
#       <localname>Ελληνική Δημοκρατία</localname>
#       <population measured="census" year="1861">1096810</population>
#       <population measured="census" year="1870">1457894</population>
#       <population measured="census" year="1879">1679470</population>
#       <population measured="census" year="1896">2433806</population>
#       <population measured="census" year="1907">2631592</population>
#       <population measured="census" year="1920">5016889</population>
#       <population measured="census" year="1928">6204684</population>
#       <population measured="census" year="1940">7344860</population>
#       <population measured="census" year="1951">7632801</population>
#       <population measured="census" year="1961">8388553</population>
#       <population measured="census" year="1971">8768372</population>
#       <population measured="census" year="1981">9739589</population>
#       <population year="1991" measured="census">10217335</population>
#       <population measured="census" year="2001">10934097</population>
#       <population measured="census" year="2011">10816286</population>
#       <population_growth>0.01</population_growth>
#       <infant_mortality>4.78</infant_mortality>
#       <gdp_total>243300</gdp_total>
#       <gdp_agri>3.5</gdp_agri>
#       <gdp_ind>16</gdp_ind>
#       <gdp_serv>80.5</gdp_serv>
#       <inflation>-0.8</inflation>
#       <unemployment>27.9</unemployment>
#       <indep_date from="Ottoman Empire">1829-01-01</indep_date>
#       <government>parliamentary republic</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="93">Greek</ethnicgroup>
#       <religion percentage="98">Christian Orthodox</religion>
#       <religion percentage="1.3">Muslim</religion>
#       <language percentage="99">Greek</language>
#       <border country="AL" length="282"/>
#       <border country="MK" length="228"/>
#       <border country="BG" length="494"/>
#       <border country="TR" length="206"/>
#       <province id="prov-Greece-2" country="GR" capital="cty-Greece-Komotini">
#          <name>Anatolikis Makedonias kai Thrakis</name>
#          <localname>Ανατολικής Μακεδονίας και Θράκης</localname>
#          <area>14157</area>
#          <population measured="census" year="1991">570197</population>
#          <population year="1994">574308</population>
#          <population measured="census" year="2001">607162</population>
#          <population measured="census" year="2011">608182</population>
#          <city id="cty-Greece-Komotini" country="GR" province="prov-Greece-2">
#             <name>Komotini</name>
#          </city>
#          <city id="cty-Greece-9" country="GR" province="prov-Greece-2">
#             <name>Kavala</name>
#             <population year="1981">56705</population>
#             <population year="1991" measured="census">60187</population>
#             <population year="2001" measured="census">63774</population>
#             <population year="2011" measured="census">58790</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#       </province>
#       <province id="prov-Greece-3" country="GR" capital="cty-Greece-Athens">
#          <name>Attikis</name>
#          <localname>Αττικής</localname>
#          <area>3808</area>
#          <population measured="census" year="1991">3594817</population>
#          <population year="1994">3522769</population>
#          <population measured="census" year="2001">3894573</population>
#          <population measured="census" year="2011">3828434</population>
#          <city id="cty-Greece-Athens" country="GR" province="prov-Greece-3">
#             <name>Athina</name>
#             <localname>Αθήνα</localname>
#             <latitude>38.0</latitude>
#             <longitude>23.75</longitude>
#             <population year="1981">885737</population>
#             <population year="1991" measured="census">816556</population>
#             <population year="2001" measured="census">789166</population>
#             <population year="2011" measured="census">664046</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-4" country="GR" province="prov-Greece-3">
#             <name>Peiraias</name>
#             <name>Piräus</name>
#             <localname>Πειραιάς</localname>
#             <population year="1981">196389</population>
#             <population year="1991" measured="census">187399</population>
#             <population year="2001" measured="census">181933</population>
#             <population year="2011" measured="census">163688</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-Peristeri" country="GR" province="prov-Greece-3">
#             <name>Peristeri</name>
#             <localname>Περιστέρι</localname>
#             <population year="1991" measured="census">141971</population>
#             <population year="2001" measured="census">146743</population>
#             <population year="2011" measured="census">139981</population>
#          </city>
#          <city id="cty-Greece-Acharnes" country="GR" province="prov-Greece-3">

# %% [markdown]
# Print the last ten thousand characters of the document to see what it looks like.

# %%
end = len(etree.tostring(document, encoding='utf-8', pretty_print=True).decode())
start = end - 10000

print(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode()[start:end])
# Out:
# </name>
#       <latitude>21.152886</latitude>
#       <longitude>-157.096256</longitude>
#       <elevation>138</elevation>
#       <gmtOffset>-10</gmtOffset>
#       <located_on island="island-Molokai"/>
#    </airport>
#    <airport iatacode="OGG" country="USA">
#       <name>Kahului</name>
#       <latitude>20.89865</latitude>
#       <longitude>-156.430458</longitude>
#       <elevation>16</elevation>
#       <gmtOffset>-10</gmtOffset>
#       <located_on island="island-Maui"/>
#    </airport>
#    <airport iatacode="MVD" city="cty-Uruguay-Montevideo" country="ROU">
#       <name>Carrasco Intl</name>
#       <latitude>-34.838417</latitude>
#       <longitude>-56.030806</longitude>
#       <elevation>32</elevation>
#       <gmtOffset>-3</gmtOffset>
#    </airport>
#    <airport iatacode="BHK" city="cty-Uzbekistan-6" country="UZB">
#       <name>Bukhara</name>
#       <latitude>39.775</latitude>
#       <longitude>64.483333</longitude>
#       <elevation>229</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="UGC" city="cty-Uzbekistan-13" country="UZB">
#       <name>Urgench Airport</name>
#       <latitude>41.5843</latitude>
#       <longitude>60.6417</longitude>
#       <elevation>98</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="TMJ" city="cty-Uzbekistan-Termiz" country="UZB">
#       <name>Termez Airport</name>
#       <latitude>37.286667</latitude>
#       <longitude>67.31</longitude>
#       <elevation>313</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="TAS" city="cty-Uzbekistan-Tashkent" country="UZB">
#       <name>Yuzhny</name>
#       <latitude>41.257861</latitude>
#       <longitude>69.281186</longitude>
#       <elevation>432</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="NCU" city="cty-Uzbekistan-9" country="UZB">
#       <name>Nukus Airport</name>
#       <latitude>42.4884</latitude>
#       <longitude>59.6233</longitude>
#       <elevation>75</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="FEG" city="cty-Uzbekistan-7" country="UZB">
#       <name>Fergana Airport</name>
#       <latitude>40.3588</latitude>
#       <longitude>71.745</longitude>
#       <elevation>604</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="SKD" city="cty-Uzbekistan-3" country="UZB">
#       <name>Samarkand</name>
#       <latitude>39.700547</latitude>
#       <longitude>66.983829</longitude>
#       <elevation>678</elevation>
#       <gmtOffset>5</gmtOffset>
#    </airport>
#    <airport iatacode="VLI" city="cty-Vanuatu-Port-Vila" country="VU">
#       <name>Port Vila Bauerfield</name>
#       <latitude>-17.699325</latitude>
#       <longitude>168.319794</longitude>
#       <elevation>21</elevation>
#       <gmtOffset>11</gmtOffset>
#       <located_on island="island-Efate"/>
#    </airport>
#    <airport iatacode="PZO" city="cty-Venezuela-6" country="YV">
#       <name>General Manuel Carlos Piar</name>
#       <latitude>8.288528</latitude>
#       <longitude>-62.760361</longitude>
#       <elevation>144</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="BLA" city="cty-Venezuela-10" country="YV">
#       <name>General Jose Antonio Anzoategui Intl</name>
#       <latitude>10.107139</latitude>
#       <longitude>-64.689161</longitude>
#       <elevation>8</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="PYH" city="cty-Venezuela-Puerto-Ayacucho" country="YV">
#       <name>Casique Aramare</name>
#       <latitude>5.619992</latitude>
#       <longitude>-67.606103</longitude>
#       <elevation>75</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="BNS" city="cty-Venezuela-19" country="YV">
#       <name>Barinas</name>
#       <latitude>8.619575</latitude>
#       <longitude>-70.220825</longitude>
#       <elevation>203</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="BRM" city="cty-Venezuela-5" country="YV">
#       <name>Barquisimeto Intl</name>
#       <latitude>10.042747</latitude>
#       <longitude>-69.358619</longitude>
#       <elevation>623</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="MAR" city="cty-Venezuela-Maracaibo" country="YV">
#       <name>La Chinita Intl</name>
#       <latitude>10.558208</latitude>
#       <longitude>-71.727856</longitude>
#       <elevation>72</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="VLN" city="cty-Venezuela-4" country="YV">
#       <name>Arturo Michelena Intl</name>
#       <latitude>10.149733</latitude>
#       <longitude>-67.9284</longitude>
#       <elevation>432</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="MUN" city="cty-Venezuela-13" country="YV">
#       <name>Maturin</name>
#       <latitude>9.749067</latitude>
#       <longitude>-63.1534</longitude>
#       <elevation>68</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="CCS" city="cty-Venezuela-Caracas" country="YV">
#       <name>Simon Bolivar Intl</name>
#       <latitude>10.603117</latitude>
#       <longitude>-66.990583</longitude>
#       <elevation>72</elevation>
#       <gmtOffset>-4</gmtOffset>
#    </airport>
#    <airport iatacode="VKG" city="cty-Vietnam-20" country="VN">
#       <name>Rach Gia</name>
#       <latitude>9.949676</latitude>
#       <longitude>105.133659</longitude>
#       <elevation>2</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="VII" city="cty-Vietnam-18" country="VN">
#       <name>Vinh Airport</name>
#       <latitude>18.737569</latitude>
#       <longitude>105.670764</longitude>
#       <elevation>7</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="SGN" city="cty-Vietnam-2" country="VN">
#       <name>Tansonnhat Intl</name>
#       <latitude>10.818797</latitude>
#       <longitude>106.651856</longitude>
#       <elevation>10</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="HAN" city="cty-Vietnam-Hanoi" country="VN">
#       <name>Noibai Intl</name>
#       <latitude>21.221192</latitude>
#       <longitude>105.807178</longitude>
#       <elevation>12</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="HPH" city="cty-Vietnam-4" country="VN">
#       <name>Cat Bi International Airport</name>
#       <latitude>20.819386</latitude>
#       <longitude>106.724989</longitude>
#       <elevation>2</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="VCA" city="cty-Vietnam-6" country="VN">
#       <name>Tra Noc Airport</name>
#       <latitude>10.085119</latitude>
#       <longitude>105.711922</longitude>
#       <elevation>3</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="NHA" city="cty-Vietnam-7" country="VN">
#       <name>Nha Trang</name>
#       <latitude>12.227467</latitude>
#       <longitude>109.192322</longitude>
#       <elevation>6</elevation>
#       <gmtOffset>7</gmtOffset>
#    </airport>
#    <airport iatacode="STT" city="cty-VIRG-Charlotte-Amalie" country="VIRG">
#       <name>Cyril E King</name>
#       <latitude>18.337306</latitude>
#       <longitude>-64.973361</longitude>
#       <elevation>7</elevation>
#       <gmtOffset>-4</gmtOffset>
#       <located_on island="island-SaintThomas"/>
#    </airport>
#    <airport iatacode="WLS" city="city-Mata-Utu-WAFU-WAFU" country="WAFU">
#       <name>Wallis</name>
#       <latitude>-13.238281</latitude>
#       <longitude>-176.199228</longitude>
#       <elevation>24</elevation>
#       <gmtOffset>12</gmtOffset>
#       <located_on island="island-Uvea"/>
#    </airport>
#    <airport iatacode="EUN" city="stadt-El_Aaiun-DARS-DARS" country="WSA">
#       <name>Hassan I Airport</name>
#       <latitude>27.1517</latitude>
#       <longitude>-13.2192</longitude>
#       <elevation>63</elevation>
#       <gmtOffset>0</gmtOffset>
#    </airport>
#    <airport iatacode="SAH" city="cty-Yemen-Sanaa" country="YE">
#       <name>Sanaa Intl</name>
#       <latitude>15.476258</latitude>
#       <longitude>44.219739</longitude>
#       <elevation>2200</elevation>
#       <gmtOffset>3</gmtOffset>
#    </airport>
#    <airport iatacode="HOD" city="cty-Yemen-Hodeida" country="YE">
#       <name>Hodeidah Intl</name>
#       <latitude>14.753</latitude>
#       <longitude>42.976336</longitude>
#       <elevation>13</elevation>
#       <gmtOffset>3</gmtOffset>
#    </airport>
#    <airport iatacode="TAI" city="cty-Yemen-Taiz" country="YE">
#       <name>Taiz Intl</name>
#       <latitude>13.685964</latitude>
#       <longitude>44.139056</longitude>
#       <elevation>1475</elevation>
#       <gmtOffset>3</gmtOffset>
#    </airport>
#    <airport iatacode="ADE" city="cty-Yemen-Aden" country="YE">
#       <name>Aden Intl</name>
#       <latitude>12.829542</latitude>
#       <longitude>45.028792</longitude>
#       <elevation>2</elevation>
#       <gmtOffset>3</gmtOffset>
#    </airport>
#    <airport iatacode="LVI" city="cty-Zambia-Livingstone" country="Z">
#       <name>Livingstone</name>
#       <latitude>-17.821756</latitude>
#       <longitude>25.822692</longitude>
#       <elevation>1007</elevation>
#       <gmtOffset>2</gmtOffset>
#    </airport>
#    <airport iatacode="NLA" city="cty-Zambia-3" country="Z">
#       <name>Ndola</name>
#       <latitude>-12.998139</latitude>
#       <longitude>28.664944</longitude>
#       <elevation>1270</elevation>
#       <gmtOffset>2</gmtOffset>
#    </airport>
#    <airport iatacode="LUN" city="cty-Zambia-2" country="Z">
#       <name>Lusaka Intl</name>
#       <latitude>-15.330817</latitude>
#       <longitude>28.452628</longitude>
#       <elevation>1152</elevation>
#       <gmtOffset>2</gmtOffset>
#    </airport>
#    <airport iatacode="BUQ" city="cty-Zimbabwe-2" country="ZW">
#       <name>J M Nkomo Intl</name>
#       <latitude>-20.017431</latitude>
#       <longitude>28.617869</longitude>
#       <elevation>1329</elevation>
#       <gmtOffset>2</gmtOffset>
#    </airport>
#    <airport iatacode="HRE" city="cty-Zimbabwe-1" country="ZW">
#       <name>Harare Intl</name>
#       <latitude>-17.931806</latitude>
#       <longitude>31.092847</longitude>
#       <elevation>1490</elevation>
#       <gmtOffset>2</gmtOffset>
#    </airport>
# </mondial>

# %% [markdown]
# Print the middle ten thousand characters of the document to see what it looks like.

# %%
doc_length = len(etree.tostring(document, encoding='utf-8', pretty_print=True).decode())

start = round(doc_length / 2) - round(10000 / 2)
end = round(doc_length / 2) + round(10000 / 2)

print(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode()[start:end])
# Out:
# try="USA" province="prov-United-States-40">
#             <name>Providence</name>
#             <latitude>41.7333</latitude>
#             <longitude>-71.4333</longitude>
#             <population measured="census" year="1980">156804</population>
#             <population year="1990" measured="census">160728</population>
#             <population measured="census" year="2000">173525</population>
#             <population measured="census" year="2010">178042</population>
#             <located_at watertype="sea" sea="sea-Atlantic"/>
#          </city>
#       </province>
#       <province id="prov-United-States-41" country="USA" capital="cty-United-States-179">
#          <name>South Carolina</name>
#          <area>77857</area>
#          <population measured="census" year="1980">3121820</population>
#          <population measured="census" year="1990">3486703</population>
#          <population measured="census" year="2000">4012012</population>
#          <population measured="census" year="2010">4625364</population>
#          <population measured="estimate" year="2014">4832482</population>
#          <city id="cty-United-States-179" country="USA" province="prov-United-States-41">
#             <name>Columbia</name>
#             <latitude>33.95</latitude>
#             <longitude>-81.1167</longitude>
#             <population year="1990" measured="census">110734</population>
#             <population measured="census" year="2000">118135</population>
#             <population measured="census" year="2010">130038</population>
#          </city>
#       </province>
#       <province id="prov-United-States-42" country="USA" capital="cty-United-States-Pierre">
#          <name>South Dakota</name>
#          <area>196350</area>
#          <population measured="census" year="1980">690768</population>
#          <population measured="census" year="1990">696004</population>
#          <population measured="census" year="2000">754844</population>
#          <population measured="census" year="2010">814180</population>
#          <population measured="estimate" year="2014">853175</population>
#          <city id="cty-United-States-177" country="USA" province="prov-United-States-42">
#             <name>Sioux Falls</name>
#             <latitude>43.5667</latitude>
#             <longitude>-96.7333</longitude>
#             <population measured="census" year="1980">81343</population>
#             <population measured="census" year="1990">100814</population>
#             <population measured="census" year="2000">124728</population>
#             <population measured="census" year="2010">153897</population>
#          </city>
#          <city id="cty-United-States-Pierre" country="USA" province="prov-United-States-42">
#             <name>Pierre</name>
#             <latitude>44.3833</latitude>
#             <longitude>-100.283</longitude>
#             <population year="1980" measured="census">11973</population>
#             <population year="1990" measured="census">12906</population>
#             <population year="2000" measured="census">13881</population>
#             <population year="2010" measured="census">13646</population>
#             <located_at watertype="river" river="river-Missouri_River"/>
#             <located_at watertype="lake" lake="lake-LakeOahe"/>
#          </city>
#       </province>
#       <province id="prov-United-States-43" country="USA" capital="cty-United-States-Nashville">
#          <name>Tennessee</name>
#          <area>106798</area>
#          <population measured="census" year="1980">4591120</population>
#          <population measured="census" year="1990">4877185</population>
#          <population measured="census" year="2000">5689283</population>
#          <population measured="census" year="2010">6346105</population>
#          <population measured="estimate" year="2014">6549352</population>
#          <city id="cty-United-States-19" country="USA" province="prov-United-States-43">
#             <name>Memphis</name>
#             <latitude>35.05</latitude>
#             <longitude>-90</longitude>
#             <population year="1990" measured="census">610337</population>
#             <population year="2000" measured="census">650100</population>
#             <population measured="census" year="2010">646872</population>
#             <population year="2013" measured="estimate">653450</population>
#             <located_at watertype="river" river="river-Mississippi_River"/>
#          </city>
#          <city id="cty-United-States-Nashville" country="USA" province="prov-United-States-43">
#             <name>Nashville-Davidson</name>
#             <latitude>36.1</latitude>
#             <longitude>-86.4</longitude>
#             <population measured="census" year="1980">455651</population>
#             <population year="1990" measured="census">510784</population>
#             <population measured="census" year="2000">545659</population>
#             <population measured="census" year="2010">603527</population>
#             <population year="2013" measured="estimate">634464</population>
#          </city>
#          <city id="cty-United-States-114" country="USA" province="prov-United-States-43">
#             <name>Knoxville</name>
#             <latitude>35.8167</latitude>
#             <longitude>-83.9833</longitude>
#             <population year="1990" measured="census">169761</population>
#             <population measured="census" year="2000">173812</population>
#             <population measured="census" year="2010">178765</population>
#             <located_at watertype="river" river="river-TennesseeRiver"/>
#          </city>
#          <city id="cty-United-States-126" country="USA" province="prov-United-States-43">
#             <name>Chattanooga</name>
#             <latitude>35.0333</latitude>
#             <longitude>-85.2</longitude>
#             <population measured="census" year="1980">169514</population>
#             <population measured="census" year="1990">152466</population>
#             <population measured="census" year="2000">156472</population>
#             <population measured="census" year="2010">168828</population>
#             <located_at watertype="river" river="river-TennesseeRiver"/>
#          </city>
#       </province>
#       <province id="prov-United-States-44" country="USA" capital="cty-United-States-23">
#          <name>Texas</name>
#          <area>676587</area>
#          <population measured="census" year="1980">14229191</population>
#          <population measured="census" year="1990">16986510</population>
#          <population measured="census" year="2000">20851820</population>
#          <population measured="census" year="2010">25145561</population>
#          <population measured="estimate" year="2014">26956958</population>
#          <city id="cty-United-States-5" country="USA" province="prov-United-States-44">
#             <name>Houston</name>
#             <latitude>29.9667</latitude>
#             <longitude>-95.35</longitude>
#             <population measured="census" year="1980">1595138</population>
#             <population year="1990" measured="census">1630553</population>
#             <population measured="census" year="2000">1973648</population>
#             <population measured="census" year="2010">2096798</population>
#             <population year="2013" measured="estimate">2195914</population>
#          </city>
#          <city id="cty-United-States-9" country="USA" province="prov-United-States-44">
#             <name>San Antonio</name>
#             <latitude>29.3</latitude>
#             <longitude>-98.4</longitude>
#             <population measured="census" year="1980">785940</population>
#             <population year="1990" measured="census">935933</population>
#             <population measured="census" year="2000">1151314</population>
#             <population measured="census" year="2010">1327558</population>
#             <population year="2013" measured="estimate">1409019</population>
#          </city>
#          <city id="cty-United-States-10" country="USA" province="prov-United-States-44">
#             <name>Dallas</name>
#             <latitude>32.85</latitude>
#             <longitude>-96.85</longitude>
#             <population measured="census" year="1980">904599</population>
#             <population year="1990" measured="census">1006877</population>
#             <population measured="census" year="2000">1187742</population>
#             <population measured="census" year="2010">1197787</population>
#             <population year="2013" measured="estimate">1257676</population>
#          </city>
#          <city id="cty-United-States-18" country="USA" province="prov-United-States-44">
#             <name>El Paso</name>
#             <population measured="census" year="1980">425259</population>
#             <population year="1990" measured="census">515342</population>
#             <population measured="census" year="2000">566896</population>
#             <population measured="census" year="2010">649133</population>
#             <population year="2013" measured="estimate">674433</population>
#             <located_at watertype="river" river="river-RioGrande"/>
#          </city>
#          <city id="cty-United-States-23" country="USA" province="prov-United-States-44">
#             <name>Austin</name>
#             <latitude>30.3</latitude>
#             <longitude>-97.7</longitude>
#             <population measured="census" year="1980">345890</population>
#             <population year="1990" measured="census">465622</population>
#             <population measured="census" year="2000">670654</population>
#             <population measured="census" year="2010">810759</population>
#             <population year="2013" measured="estimate">885400</population>
#          </city>
#          <city id="cty-United-States-29" country="USA" province="prov-United-States-44">
#             <name>Fort Worth</name>
#             <latitude>32.4</latitude>
#             <longitude>-97.1</longitude>
#             <population measured="census" year="1980">385164</population>
#             <population year="1990" measured="census">447619</population>
#             <population measured="census" year="2000">543044</population>

# %% [markdown]
# ### Problem 1. Find the 10 countries with the lowest infant mortality rates

# %% [markdown]
# #### What is the infant mortality rate?
#
# **Infant mortality** refers to deaths of young children, typically those less than one year of age. It is measured by the **infant mortality rate** (**IMR**), which is **the number of deaths of children under one year of age per 1000 live births**.
#
# [See https://en.wikipedia.org/wiki/Infant_mortality]

# %%
country_list = []

for element in document.iterfind('country'):
    country_list.append(element.find('name').text)

country_list = sorted(country_list)
country_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Ceuta',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos Islands',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Cote dIvoire',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia',
#  'Gaza Strip',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Holy See',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Melilla',
#  'Mexico',
#  'Micronesia',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Niue',
#  'Norfolk Island',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Pitcairn',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Svalbard',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'Virgin Islands',
#  'Wallis and Futuna',
#  'West Bank',
#  'Western Sahara',
#  'Yemen',
#  'Zaire',
#  'Zambia',
#  'Zimbabwe']

# %%
len(country_list)
# Out:
# 244

# %%
# are all unique?

len(country_list) == len(set(country_list))
# Out:
# True

# %% [markdown]
# Let look at the raw data and see if there is a .tag attribute that might indicate an element with infant mortality data.

# %%
print(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode()[0:10000])
# Out:
# <!DOCTYPE mondial SYSTEM "mondial.dtd">
# <mondial>
#    <country car_code="AL" area="28750" capital="cty-Albania-Tirane" memberships="org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO">
#       <name>Albania</name>
#       <population measured="est." year="1950">1214489</population>
#       <population measured="est." year="1960">1618829</population>
#       <population measured="est." year="1970">2138966</population>
#       <population measured="est." year="1980">2734776</population>
#       <population measured="est." year="1990">3446882</population>
#       <population year="1997">3249136</population>
#       <population measured="est." year="2000">3304948</population>
#       <population year="2001" measured="census">3069275</population>
#       <population year="2011" measured="census">2800138</population>
#       <population_growth>0.3</population_growth>
#       <infant_mortality>13.19</infant_mortality>
#       <gdp_total>12800</gdp_total>
#       <gdp_agri>19.5</gdp_agri>
#       <gdp_ind>12</gdp_ind>
#       <gdp_serv>68.5</gdp_serv>
#       <inflation>1.7</inflation>
#       <unemployment>16.9</unemployment>
#       <indep_date from="Ottoman Empire">1912-11-28</indep_date>
#       <government>parliamentary democracy</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="95">Albanian</ethnicgroup>
#       <ethnicgroup percentage="3">Greek</ethnicgroup>
#       <religion percentage="70">Muslim</religion>
#       <religion percentage="10">Roman Catholic</religion>
#       <religion percentage="20">Christian Orthodox</religion>
#       <language percentage="98.8">Albanian</language>
#       <language percentage="0.5">Greek</language>
#       <border country="GR" length="282"/>
#       <border country="MK" length="151"/>
#       <border country="MNE" length="172"/>
#       <border country="KOS" length="112"/>
#       <city id="cty-Albania-Tirane" country="AL">
#          <name>Tirana</name>
#          <name>Tirane</name>
#          <latitude>41.3</latitude>
#          <longitude>19.8</longitude>
#          <population year="1987">192000</population>
#          <population year="1990" measured="estimate">244153</population>
#          <population year="2011" measured="census">418495</population>
#       </city>
#       <city id="stadt-Shkoder-AL-AL" country="AL">
#          <name>Shkodër</name>
#          <latitude>42.2</latitude>
#          <longitude>19.2</longitude>
#          <population year="1987">62000</population>
#          <population year="2011" measured="census">77075</population>
#          <located_at watertype="lake" lake="lake-Skutarisee"/>
#       </city>
#       <city id="stadt-Durres-AL-AL" country="AL">
#          <name>Durrës</name>
#          <latitude>41.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">60000</population>
#          <population year="2011" measured="census">113249</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Vlore-AL-AL" country="AL">
#          <name>Vlorë</name>
#          <latitude>40.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">56000</population>
#          <population year="2011" measured="census">79513</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Elbasan-AL-AL" country="AL">
#          <name>Elbasan</name>
#          <latitude>41.1</latitude>
#          <longitude>20.1</longitude>
#          <population year="1987">53000</population>
#          <population year="2011" measured="census">78703</population>
#       </city>
#       <city id="stadt-Korce-AL-AL" country="AL">
#          <name>Korçë</name>
#          <latitude>40.4</latitude>
#          <longitude>20.5</longitude>
#          <population year="1987">52000</population>
#          <population year="2011" measured="census">51152</population>
#       </city>
#    </country>
#    <country car_code="GR" area="131940" capital="cty-Greece-Athens" memberships="org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC">
#       <name>Greece</name>
#       <localname>Ελληνική Δημοκρατία</localname>
#       <population measured="census" year="1861">1096810</population>
#       <population measured="census" year="1870">1457894</population>
#       <population measured="census" year="1879">1679470</population>
#       <population measured="census" year="1896">2433806</population>
#       <population measured="census" year="1907">2631592</population>
#       <population measured="census" year="1920">5016889</population>
#       <population measured="census" year="1928">6204684</population>
#       <population measured="census" year="1940">7344860</population>
#       <population measured="census" year="1951">7632801</population>
#       <population measured="census" year="1961">8388553</population>
#       <population measured="census" year="1971">8768372</population>
#       <population measured="census" year="1981">9739589</population>
#       <population year="1991" measured="census">10217335</population>
#       <population measured="census" year="2001">10934097</population>
#       <population measured="census" year="2011">10816286</population>
#       <population_growth>0.01</population_growth>
#       <infant_mortality>4.78</infant_mortality>
#       <gdp_total>243300</gdp_total>
#       <gdp_agri>3.5</gdp_agri>
#       <gdp_ind>16</gdp_ind>
#       <gdp_serv>80.5</gdp_serv>
#       <inflation>-0.8</inflation>
#       <unemployment>27.9</unemployment>
#       <indep_date from="Ottoman Empire">1829-01-01</indep_date>
#       <government>parliamentary republic</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="93">Greek</ethnicgroup>
#       <religion percentage="98">Christian Orthodox</religion>
#       <religion percentage="1.3">Muslim</religion>
#       <language percentage="99">Greek</language>
#       <border country="AL" length="282"/>
#       <border country="MK" length="228"/>
#       <border country="BG" length="494"/>
#       <border country="TR" length="206"/>
#       <province id="prov-Greece-2" country="GR" capital="cty-Greece-Komotini">
#          <name>Anatolikis Makedonias kai Thrakis</name>
#          <localname>Ανατολικής Μακεδονίας και Θράκης</localname>
#          <area>14157</area>
#          <population measured="census" year="1991">570197</population>
#          <population year="1994">574308</population>
#          <population measured="census" year="2001">607162</population>
#          <population measured="census" year="2011">608182</population>
#          <city id="cty-Greece-Komotini" country="GR" province="prov-Greece-2">
#             <name>Komotini</name>
#          </city>
#          <city id="cty-Greece-9" country="GR" province="prov-Greece-2">
#             <name>Kavala</name>
#             <population year="1981">56705</population>
#             <population year="1991" measured="census">60187</population>
#             <population year="2001" measured="census">63774</population>
#             <population year="2011" measured="census">58790</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#       </province>
#       <province id="prov-Greece-3" country="GR" capital="cty-Greece-Athens">
#          <name>Attikis</name>
#          <localname>Αττικής</localname>
#          <area>3808</area>
#          <population measured="census" year="1991">3594817</population>
#          <population year="1994">3522769</population>
#          <population measured="census" year="2001">3894573</population>
#          <population measured="census" year="2011">3828434</population>
#          <city id="cty-Greece-Athens" country="GR" province="prov-Greece-3">
#             <name>Athina</name>
#             <localname>Αθήνα</localname>
#             <latitude>38.0</latitude>
#             <longitude>23.75</longitude>
#             <population year="1981">885737</population>
#             <population year="1991" measured="census">816556</population>
#             <population year="2001" measured="census">789166</population>
#             <population year="2011" measured="census">664046</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-4" country="GR" province="prov-Greece-3">
#             <name>Peiraias</name>
#             <name>Piräus</name>
#             <localname>Πειραιάς</localname>
#             <population year="1981">196389</population>
#             <population year="1991" measured="census">187399</population>
#             <population year="2001" measured="census">181933</population>
#             <population year="2011" measured="census">163688</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-Peristeri" country="GR" province="prov-Greece-3">
#             <name>Peristeri</name>
#             <localname>Περιστέρι</localname>
#             <population year="1991" measured="census">141971</population>
#             <population year="2001" measured="census">146743</population>
#             <population year="2011" measured="census">139981</population>
#          </city>
#          <city id="cty-Greece-Acharnes" country="GR" province="prov-Greece-3">

# %% [markdown]
# There is an 'infant_mortality' .tag attribute.  We'll use this to extract infant mortality data.

# %%
infant_mortality_dict = {}

# %%
for element in document.iterfind('country'):
    im_list = []
    for subelement in element.getiterator('infant_mortality'):
        im_list += subelement.text
    infant_mortality_dict.update({element.find('name').text : im_list})

# %%
infant_mortality_dict = {}

for element in document.iterfind('country'):
    try:
        infant_mortality_dict.update({element.find('name').text : float(element.find('infant_mortality').text)})
    except:
        infant_mortality_dict.update({element.find('name').text : np.nan})

infant_mortality_dict
# Out:
# {'Afghanistan': 117.23,
#  'Albania': 13.19,
#  'Algeria': 21.76,
#  'American Samoa': 8.92,
#  'Andorra': 3.69,
#  'Angola': 79.99,
#  'Anguilla': 3.4,
#  'Antigua and Barbuda': 13.29,
#  'Argentina': 9.96,
#  'Armenia': 13.97,
#  'Aruba': 11.74,
#  'Australia': 4.43,
#  'Austria': 4.16,
#  'Azerbaijan': 26.67,
#  'Bahamas': 12.5,
#  'Bahrain': 9.68,
#  'Bangladesh': 45.67,
#  'Barbados': 10.93,
#  'Belarus': 3.64,
#  'Belgium': 4.18,
#  'Belize': 20.31,
#  'Benin': 57.09,
#  'Bermuda': 2.48,
#  'Bhutan': 37.89,
#  'Bolivia': 38.61,
#  'Bosnia and Herzegovina': 5.84,
#  'Botswana': 9.38,
#  'Brazil': 19.21,
#  'British Virgin Islands': 13.45,
#  'Brunei': 10.48,
#  'Bulgaria': 15.08,
#  'Burkina Faso': 76.8,
#  'Burundi': 63.44,
#  'Cambodia': 51.36,
#  'Cameroon': 55.1,
#  'Canada': 4.71,
#  'Cape Verde': 24.28,
#  'Cayman Islands': 6.21,
#  'Central African Republic': 92.86,
#  'Ceuta': nan,
#  'Chad': 90.3,
#  'Chile': 7.02,
#  'China': 14.79,
#  'Christmas Island': nan,
#  'Cocos Islands': nan,
#  'Colombia': 15.02,
#  'Comoros': 65.31,
#  'Congo': 59.34,
#  'Cook Islands': 14.33,
#  'Costa Rica': 8.7,
#  'Cote dIvoire': 60.16,
#  'Croatia': 5.87,
#  'Cuba': 4.7,
#  'Curacao': nan,
#  'Cyprus': 8.54,
#  'Czech Republic': 2.63,
#  'Denmark': 4.1,
#  'Djibouti': 50.2,
#  'Dominica': 11.61,
#  'Dominican Republic': 19.63,
#  'Ecuador': 17.93,
#  'Egypt': 22.41,
#  'El Salvador': 18.44,
#  'Equatorial Guinea': 71.12,
#  'Eritrea': 38.44,
#  'Estonia': 6.7,
#  'Ethiopia': 55.77,
#  'Falkland Islands': nan,
#  'Faroe Islands': 5.71,
#  'Fiji': 10.2,
#  'Finland': 3.36,
#  'France': 3.31,
#  'French Guiana': 14.6,
#  'French Polynesia': 4.78,
#  'Gabon': 47.03,
#  'Gambia': 65.74,
#  'Gaza Strip': 30.6,
#  'Georgia': 16.68,
#  'Germany': 3.46,
#  'Ghana': 38.52,
#  'Gibraltar': 6.29,
#  'Greece': 4.78,
#  'Greenland': 9.42,
#  'Grenada': 10.5,
#  'Guadeloupe': 8.3,
#  'Guam': 5.51,
#  'Guatemala': 23.51,
#  'Guernsey': 3.47,
#  'Guinea': 55.24,
#  'Guinea-Bissau': 90.92,
#  'Guyana': 33.56,
#  'Haiti': 49.43,
#  'Holy See': nan,
#  'Honduras': 18.72,
#  'Hong Kong': 2.73,
#  'Hungary': 5.09,
#  'Iceland': 3.15,
#  'India': 43.19,
#  'Indonesia': 25.16,
#  'Iran': 39.0,
#  'Iraq': 37.53,
#  'Ireland': 3.74,
#  'Isle of Man': 4.17,
#  'Israel': 3.98,
#  'Italy': 3.31,
#  'Jamaica': 13.69,
#  'Japan': 2.13,
#  'Jersey': 3.86,
#  'Jordan': 15.73,
#  'Kazakhstan': 21.61,
#  'Kenya': 40.71,
#  'Kiribati': 35.37,
#  'Kosovo': nan,
#  'Kuwait': 7.51,
#  'Kyrgyzstan': 28.71,
#  'Laos': 54.53,
#  'Latvia': 7.91,
#  'Lebanon': 7.98,
#  'Lesotho': 50.48,
#  'Liberia': 69.19,
#  'Libya': 11.87,
#  'Liechtenstein': 4.33,
#  'Lithuania': 6.0,
#  'Luxembourg': 4.28,
#  'Macao': 3.13,
#  'Macedonia': 7.9,
#  'Madagascar': 44.88,
#  'Malawi': 48.01,
#  'Malaysia': 13.69,
#  'Maldives': 24.59,
#  'Mali': 104.34,
#  'Malta': 3.59,
#  'Marshall Islands': 21.39,
#  'Martinique': 7.1,
#  'Mauritania': 56.06,
#  'Mauritius': 10.59,
#  'Mayotte': 56.29,
#  'Melilla': nan,
#  'Mexico': 12.58,
#  'Micronesia': 21.93,
#  'Moldova': 12.93,
#  'Monaco': 1.81,
#  'Mongolia': 23.15,
#  'Montenegro': nan,
#  'Montserrat': 13.66,
#  'Morocco': 24.52,
#  'Mozambique': 72.42,
#  'Myanmar': 44.91,
#  'Namibia': 45.64,
#  'Nauru': 8.21,
#  'Nepal': 40.43,
#  'Netherlands': 3.66,
#  'New Caledonia': 5.46,
#  'New Zealand': 4.59,
#  'Nicaragua': 20.36,
#  'Niger': 86.27,
#  'Nigeria': 74.09,
#  'Niue': nan,
#  'Norfolk Island': nan,
#  'North Korea': 24.5,
#  'Northern Mariana Islands': 5.5,
#  'Norway': 2.48,
#  'Oman': 14.0,
#  'Pakistan': 57.48,
#  'Palau': 11.46,
#  'Panama': 10.7,
#  'Papua New Guinea': 39.67,
#  'Paraguay': 20.75,
#  'Peru': 20.21,
#  'Philippines': 17.64,
#  'Pitcairn': nan,
#  'Poland': 6.19,
#  'Portugal': 4.48,
#  'Puerto Rico': 7.73,
#  'Qatar': 6.42,
#  'Reunion': 7.5,
#  'Romania': 10.16,
#  'Russia': 7.08,
#  'Rwanda': 59.59,
#  'Saint Barthelemy': nan,
#  'Saint Helena': 17.63,
#  'Saint Kitts and Nevis': 8.98,
#  'Saint Lucia': 11.75,
#  'Saint Martin': nan,
#  'Saint Pierre and Miquelon': 6.95,
#  'Saint Vincent and the Grenadines': 13.07,
#  'Samoa': 20.5,
#  'San Marino': 4.52,
#  'Sao Tome and Principe': 49.16,
#  'Saudi Arabia': 14.58,
#  'Senegal': 52.72,
#  'Serbia': 6.16,
#  'Seychelles': 10.77,
#  'Sierra Leone': 73.29,
#  'Singapore': 2.53,
#  'Sint Maarten': 9.05,
#  'Slovakia': 5.35,
#  'Slovenia': 4.04,
#  'Solomon Islands': 16.17,
#  'Somalia': 100.14,
#  'South Africa': 41.61,
#  'South Korea': 3.93,
#  'South Sudan': 68.16,
#  'Spain': 3.33,
#  'Sri Lanka': 9.02,
#  'Sudan': 52.86,
#  'Suriname': 27.07,
#  'Svalbard': nan,
#  'Swaziland': 54.82,
#  'Sweden': 2.6,
#  'Switzerland': 3.73,
#  'Syria': 15.79,
#  'Taiwan': 4.49,
#  'Tajikistan': 35.03,
#  'Tanzania': 43.74,
#  'Thailand': 9.86,
#  'Timor-Leste': 38.79,
#  'Togo': 46.73,
#  'Tokelau': nan,
#  'Tonga': 12.36,
#  'Trinidad and Tobago': 24.82,
#  'Tunisia': 23.19,
#  'Turkey': 21.43,
#  'Turkmenistan': 38.13,
#  'Turks and Caicos Islands': 10.97,
#  'Tuvalu': 31.69,
#  'Uganda': 60.82,
#  'Ukraine': 8.1,
#  'United Arab Emirates': 10.92,
#  'United Kingdom': 4.44,
#  'United States': 6.17,
#  'Uruguay': 8.97,
#  'Uzbekistan': 19.84,
#  'Vanuatu': 16.41,
#  'Venezuela': 19.33,
#  'Vietnam': 18.99,
#  'Virgin Islands': 6.79,
#  'Wallis and Futuna': 4.49,
#  'West Bank': 28.6,
#  'Western Sahara': 145.82,
#  'Yemen': 50.41,
#  'Zaire': 73.15,
#  'Zambia': 66.62,
#  'Zimbabwe': 26.55}

# %%
infant_mortality_df = pd.DataFrame()

# %%
infant_mortality_df = infant_mortality_df.from_dict(infant_mortality_dict, orient='index')

# %%
infant_mortality_df.head()
# Out:
#                 0
# Albania     13.19
# Greece       4.78
# Macedonia    7.90
# Serbia       6.16
# Montenegro    NaN

# %%
infant_mortality_df.index.name = 'country'
infant_mortality_df.head()
# Out:
#                 0
# country
# Albania     13.19
# Greece       4.78
# Macedonia    7.90
# Serbia       6.16
# Montenegro    NaN

# %%
infant_mortality_df.rename(columns={0: 'infant_mortality'}, inplace=True)

# %%
infant_mortality_df.head()
# Out:
#             infant_mortality
# country
# Albania                13.19
# Greece                  4.78
# Macedonia               7.90
# Serbia                  6.16
# Montenegro               NaN

# %% [markdown]
# Blind spots:

# %%
infant_mortality_df[infant_mortality_df.infant_mortality.isnull()]
# Out:
#                   infant_mortality
# country
# Montenegro                     NaN
# Kosovo                         NaN
# Holy See                       NaN
# Ceuta                          NaN
# Melilla                        NaN
# Svalbard                       NaN
# Christmas Island               NaN
# Cocos Islands                  NaN
# Curacao                        NaN
# Saint Martin                   NaN
# Saint Barthelemy               NaN
# Niue                           NaN
# Norfolk Island                 NaN
# Pitcairn                       NaN
# Tokelau                        NaN
# Falkland Islands               NaN

# %%
infant_mortality_df.sort_values('infant_mortality', ascending=False, inplace=True)

# %%
infant_mortality_df.head(10)
# Out:
#                           infant_mortality
# country
# Western Sahara                      145.82
# Afghanistan                         117.23
# Mali                                104.34
# Somalia                             100.14
# Central African Republic             92.86
# Guinea-Bissau                        90.92
# Chad                                 90.30
# Niger                                86.27
# Angola                               79.99
# Burkina Faso                         76.80

# %%
infant_mortality_df.head(10).sort_values('infant_mortality').plot(kind='barh',
                                                                 grid=True)

# %%
infant_mortality_df[infant_mortality_df.notnull()].tail(20).sort_values('infant_mortality').plot(kind='barh',
                                                                 grid=True)

# %% [markdown]
# ### TO DO:
#
# + format dataframes with css
# + add documentation
# + finish other problems
# + heatmap with bokeh

# %% [markdown]
# ### Problem 2. Find the 10 cities with the largest population

# %% [markdown]
#     </city>
#           <city id="stadt-Shkoder-AL-AL" country="AL">
#              <name>Shkodër</name>
#              <latitude>42.2</latitude>
#              <longitude>19.2</longitude>
#              <population year="1987">62000</population>
#              <population year="2011" measured="census">77075</population>
#              <located_at watertype="lake" lake="lake-Skutarisee"/>

# %%
print(etree.tostring(document, 
                     encoding='utf-8', 
                     pretty_print=True).decode()[0:10000])
# Out:
# <!DOCTYPE mondial SYSTEM "mondial.dtd">
# <mondial>
#    <country car_code="AL" area="28750" capital="cty-Albania-Tirane" memberships="org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO">
#       <name>Albania</name>
#       <population measured="est." year="1950">1214489</population>
#       <population measured="est." year="1960">1618829</population>
#       <population measured="est." year="1970">2138966</population>
#       <population measured="est." year="1980">2734776</population>
#       <population measured="est." year="1990">3446882</population>
#       <population year="1997">3249136</population>
#       <population measured="est." year="2000">3304948</population>
#       <population year="2001" measured="census">3069275</population>
#       <population year="2011" measured="census">2800138</population>
#       <population_growth>0.3</population_growth>
#       <infant_mortality>13.19</infant_mortality>
#       <gdp_total>12800</gdp_total>
#       <gdp_agri>19.5</gdp_agri>
#       <gdp_ind>12</gdp_ind>
#       <gdp_serv>68.5</gdp_serv>
#       <inflation>1.7</inflation>
#       <unemployment>16.9</unemployment>
#       <indep_date from="Ottoman Empire">1912-11-28</indep_date>
#       <government>parliamentary democracy</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="95">Albanian</ethnicgroup>
#       <ethnicgroup percentage="3">Greek</ethnicgroup>
#       <religion percentage="70">Muslim</religion>
#       <religion percentage="10">Roman Catholic</religion>
#       <religion percentage="20">Christian Orthodox</religion>
#       <language percentage="98.8">Albanian</language>
#       <language percentage="0.5">Greek</language>
#       <border country="GR" length="282"/>
#       <border country="MK" length="151"/>
#       <border country="MNE" length="172"/>
#       <border country="KOS" length="112"/>
#       <city id="cty-Albania-Tirane" country="AL">
#          <name>Tirana</name>
#          <name>Tirane</name>
#          <latitude>41.3</latitude>
#          <longitude>19.8</longitude>
#          <population year="1987">192000</population>
#          <population year="1990" measured="estimate">244153</population>
#          <population year="2011" measured="census">418495</population>
#       </city>
#       <city id="stadt-Shkoder-AL-AL" country="AL">
#          <name>Shkodër</name>
#          <latitude>42.2</latitude>
#          <longitude>19.2</longitude>
#          <population year="1987">62000</population>
#          <population year="2011" measured="census">77075</population>
#          <located_at watertype="lake" lake="lake-Skutarisee"/>
#       </city>
#       <city id="stadt-Durres-AL-AL" country="AL">
#          <name>Durrës</name>
#          <latitude>41.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">60000</population>
#          <population year="2011" measured="census">113249</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Vlore-AL-AL" country="AL">
#          <name>Vlorë</name>
#          <latitude>40.3</latitude>
#          <longitude>19.3</longitude>
#          <population year="1987">56000</population>
#          <population year="2011" measured="census">79513</population>
#          <located_at watertype="sea" sea="sea-Mittelmeer"/>
#       </city>
#       <city id="stadt-Elbasan-AL-AL" country="AL">
#          <name>Elbasan</name>
#          <latitude>41.1</latitude>
#          <longitude>20.1</longitude>
#          <population year="1987">53000</population>
#          <population year="2011" measured="census">78703</population>
#       </city>
#       <city id="stadt-Korce-AL-AL" country="AL">
#          <name>Korçë</name>
#          <latitude>40.4</latitude>
#          <longitude>20.5</longitude>
#          <population year="1987">52000</population>
#          <population year="2011" measured="census">51152</population>
#       </city>
#    </country>
#    <country car_code="GR" area="131940" capital="cty-Greece-Athens" memberships="org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC">
#       <name>Greece</name>
#       <localname>Ελληνική Δημοκρατία</localname>
#       <population measured="census" year="1861">1096810</population>
#       <population measured="census" year="1870">1457894</population>
#       <population measured="census" year="1879">1679470</population>
#       <population measured="census" year="1896">2433806</population>
#       <population measured="census" year="1907">2631592</population>
#       <population measured="census" year="1920">5016889</population>
#       <population measured="census" year="1928">6204684</population>
#       <population measured="census" year="1940">7344860</population>
#       <population measured="census" year="1951">7632801</population>
#       <population measured="census" year="1961">8388553</population>
#       <population measured="census" year="1971">8768372</population>
#       <population measured="census" year="1981">9739589</population>
#       <population year="1991" measured="census">10217335</population>
#       <population measured="census" year="2001">10934097</population>
#       <population measured="census" year="2011">10816286</population>
#       <population_growth>0.01</population_growth>
#       <infant_mortality>4.78</infant_mortality>
#       <gdp_total>243300</gdp_total>
#       <gdp_agri>3.5</gdp_agri>
#       <gdp_ind>16</gdp_ind>
#       <gdp_serv>80.5</gdp_serv>
#       <inflation>-0.8</inflation>
#       <unemployment>27.9</unemployment>
#       <indep_date from="Ottoman Empire">1829-01-01</indep_date>
#       <government>parliamentary republic</government>
#       <encompassed continent="europe" percentage="100"/>
#       <ethnicgroup percentage="93">Greek</ethnicgroup>
#       <religion percentage="98">Christian Orthodox</religion>
#       <religion percentage="1.3">Muslim</religion>
#       <language percentage="99">Greek</language>
#       <border country="AL" length="282"/>
#       <border country="MK" length="228"/>
#       <border country="BG" length="494"/>
#       <border country="TR" length="206"/>
#       <province id="prov-Greece-2" country="GR" capital="cty-Greece-Komotini">
#          <name>Anatolikis Makedonias kai Thrakis</name>
#          <localname>Ανατολικής Μακεδονίας και Θράκης</localname>
#          <area>14157</area>
#          <population measured="census" year="1991">570197</population>
#          <population year="1994">574308</population>
#          <population measured="census" year="2001">607162</population>
#          <population measured="census" year="2011">608182</population>
#          <city id="cty-Greece-Komotini" country="GR" province="prov-Greece-2">
#             <name>Komotini</name>
#          </city>
#          <city id="cty-Greece-9" country="GR" province="prov-Greece-2">
#             <name>Kavala</name>
#             <population year="1981">56705</population>
#             <population year="1991" measured="census">60187</population>
#             <population year="2001" measured="census">63774</population>
#             <population year="2011" measured="census">58790</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#       </province>
#       <province id="prov-Greece-3" country="GR" capital="cty-Greece-Athens">
#          <name>Attikis</name>
#          <localname>Αττικής</localname>
#          <area>3808</area>
#          <population measured="census" year="1991">3594817</population>
#          <population year="1994">3522769</population>
#          <population measured="census" year="2001">3894573</population>
#          <population measured="census" year="2011">3828434</population>
#          <city id="cty-Greece-Athens" country="GR" province="prov-Greece-3">
#             <name>Athina</name>
#             <localname>Αθήνα</localname>
#             <latitude>38.0</latitude>
#             <longitude>23.75</longitude>
#             <population year="1981">885737</population>
#             <population year="1991" measured="census">816556</population>
#             <population year="2001" measured="census">789166</population>
#             <population year="2011" measured="census">664046</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-4" country="GR" province="prov-Greece-3">
#             <name>Peiraias</name>
#             <name>Piräus</name>
#             <localname>Πειραιάς</localname>
#             <population year="1981">196389</population>
#             <population year="1991" measured="census">187399</population>
#             <population year="2001" measured="census">181933</population>
#             <population year="2011" measured="census">163688</population>
#             <located_at watertype="sea" sea="sea-Mittelmeer"/>
#          </city>
#          <city id="cty-Greece-Peristeri" country="GR" province="prov-Greece-3">
#             <name>Peristeri</name>
#             <localname>Περιστέρι</localname>
#             <population year="1991" measured="census">141971</population>
#             <population year="2001" measured="census">146743</population>
#             <population year="2011" measured="census">139981</population>
#          </city>
#          <city id="cty-Greece-Acharnes" country="GR" province="prov-Greece-3">

# %%
document.find('country').find('city').find('population').attrib['year']
# Out:
# '1987'

# %%
temp = document.find('country').find('city').find('population').attrib['year']

# %%
document.find('country').find('city').find('population').values()
# Out:
# ['1987']

# %%
document.find('country').find('city').find('population').values()
# Out:
# ['1987']

# %%
document.find('country').find('city').attrib['id']

# %%
city_dict = {}

for element in document.iterfind('country'):
    for subelement in element.getiterator('city'):
        try:
            city_dict.update({subelement.attrib['id'] : subelement.find('population').attrib})
        except:
            pass

city_dict
# Out:
# {'cty-Albania-Tirane': {'year': '1987'},
#  'stadt-Shkoder-AL-AL': {'year': '1987'},
#  'stadt-Durres-AL-AL': {'year': '1987'},
#  'stadt-Vlore-AL-AL': {'year': '1987'},
#  'stadt-Elbasan-AL-AL': {'year': '1987'},
#  'stadt-Korce-AL-AL': {'year': '1987'},
#  'cty-Greece-9': {'year': '1981'},
#  'cty-Greece-Athens': {'year': '1981'},
#  'cty-Greece-4': {'year': '1981'},
#  'cty-Greece-Peristeri': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-Acharnes': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-5': {'year': '1981'},
#  'cty-Greece-Korfu': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-Ioannina': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-Thessaloniki': {'year': '1981'},
#  'cty-Greece-7': {'year': '1981'},
#  'cty-Greece-Chania': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-Rhodes': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-Lamia': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Chalkida': {'year': '1991', 'measured': 'census'},
#  'cty-Greece-6': {'year': '1981'},
#  'cty-Greece-8': {'year': '1981'},
#  'cty-Greece-Karyes': {'year': '2014'},
#  'cty-Macedonia-Skopje': {'year': '2002', 'measured': 'census'},
#  'cty-Macedonia-Kumanovo': {'year': '2002', 'measured': 'census'},
#  'city-Belgrade-SRB-SRB': {'year': '1987'},
#  'city-NoviSad-SRB-SRB': {'year': '2002', 'measured': 'census'},
#  'city-Nis-SRB-SRB': {'year': '2002', 'measured': 'census'},
#  'city-Podgorica-MNE-MNE': {'year': '2003', 'measured': 'census'},
#  'city-Pristina-KOS-KOS': {'year': '1981', 'measured': 'census'},
#  'cty-Andorra-Andorra-la-Vella': {'year': '1987'},
#  'cty-France-Strasbourg': {'year': '1990', 'measured': 'census'},
#  'cty-France-32': {'year': '1990', 'measured': 'census'},
#  'cty-France-9': {'year': '1990', 'measured': 'census'},
#  'cty-France-22': {'year': '1990', 'measured': 'census'},
#  'cty-France-31': {'year': '1990', 'measured': 'census'},
#  'cty-France-12': {'year': '1990', 'measured': 'census'},
#  'cty-France-18': {'year': '1990', 'measured': 'census'},
#  'cty-France-19': {'year': '1990', 'measured': 'census'},
#  'cty-France-34': {'year': '1990', 'measured': 'census'},
#  'cty-France-25': {'year': '1990', 'measured': 'census'},
#  'cty-France-14': {'year': '1990', 'measured': 'census'},
#  'cty-France-Ajaccio': {'year': '1990', 'measured': 'census'},
#  'cty-France-30': {'year': '1990', 'measured': 'census'},
#  'cty-France-35': {'year': '1990', 'measured': 'census'},
#  'cty-France-13': {'year': '1990', 'measured': 'census'},
#  'cty-France-Paris': {'year': '1990', 'measured': 'census'},
#  'cty-France-36': {'year': '1990', 'measured': 'census'},
#  'cty-France-38': {'year': '2006', 'measured': 'admin.'},
#  'cty-France-39': {'year': '2006', 'measured': 'admin.'},
#  'cty-France-40': {'year': '1999', 'measured': 'census'},
#  'cty-France-10': {'year': '1990', 'measured': 'census'},
#  'cty-France-26': {'year': '1990', 'measured': 'census'},
#  'cty-France-33': {'year': '1990', 'measured': 'census'},
#  'cty-France-23': {'year': '1990', 'measured': 'census'},
#  'cty-France-28': {'year': '1990', 'measured': 'census'},
#  'cty-France-37': {'year': '1990', 'measured': 'census'},
#  'cty-France-5': {'year': '1990', 'measured': 'census'},
#  'cty-France-15': {'year': '1990', 'measured': 'census'},
#  'cty-France-Nantes': {'year': '1990', 'measured': 'census'},
#  'cty-France-21': {'year': '1990', 'measured': 'census'},
#  'cty-France-20': {'year': '1990', 'measured': 'census'},
#  'cty-France-24': {'year': '1990', 'measured': 'census'},
#  'cty-France-Poitiers': {'year': '1990', 'measured': 'census'},
#  'cty-France-3': {'year': '1990', 'measured': 'census'},
#  'cty-France-Nice': {'year': '1990', 'measured': 'census'},
#  'cty-France-16': {'year': '1990', 'measured': 'census'},
#  'cty-France-27': {'year': '1990', 'measured': 'census'},
#  'cty-France-Lyon': {'year': '1990', 'measured': 'census'},
#  'cty-France-17': {'year': '1990', 'measured': 'census'},
#  'cty-France-11': {'year': '1990', 'measured': 'census'},
#  'cty-France-29': {'year': '1990', 'measured': 'census'},
#  'cty-Spain-5': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-34': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-39': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-13': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-16': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-41': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-7': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-27': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-52': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-54': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-57': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-58': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-6': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-23': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-17': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-12': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-21': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-8': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-55': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-32': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-22': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-48': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-9': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-63': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-25': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-11': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-35': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-40': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-33': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-44': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-Barcelona': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-51': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-50': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-61': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-18': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-20': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-28': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-37': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-46': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-56': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-47': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-19': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-14': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-53': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-Madrid': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-24': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-31': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-36': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-38': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-42': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-43': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-59': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-60': {'year': '2001', 'measured': 'census'},
#  'cty-Spain-62': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-10': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-30': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-29': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-49': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-Valencia': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-15': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-26': {'year': '1991', 'measured': 'census'},
#  'cty-Spain-45': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-Eisenstadt': {'year': '1981', 'measured': 'census'},
#  'cty-Austria-Klagenfurt': {'year': '1981', 'measured': 'census'},
#  'cty-Austria-Villach': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-Vienna': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-4': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-Wels': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-6': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-3': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-5': {'year': '1991', 'measured': 'census'},
#  'cty-Austria-St-Polten': {'year': '1981', 'measured': 'census'},
#  'cty-Czech-2': {'year': '1990'},
#  'cty-Czech-8': {'year': '1990'},
#  'cty-Czech-3': {'year': '1990'},
#  'cty-Czech-Karlovy': {'year': '2001', 'measured': 'census'},
#  'cty-Czech-Jihlava': {'year': '2001', 'measured': 'census'},
#  'cty-Czech-9': {'year': '1990'},
#  'cty-Czech-11': {'year': '1990'},
#  'cty-Czech-4': {'year': '1990'},
#  'cty-Czech-5': {'year': '1990'},
#  'cty-Czech-10': {'year': '1990'},
#  'cty-Czech-7': {'year': '1990'},
#  'cty-Czech-Usti-nad-Labem': {'year': '2001', 'measured': 'census'},
#  'cty-Czech-6': {'year': '1990'},
#  'cty-Germany-9': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Mannheim': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-24': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-41': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-54': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-66': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-69': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-72': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-77': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Munich': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-14': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-30': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-58': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-64': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-74': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-76': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-85': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Berlin': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-55': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-63': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-11': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-57': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Hamburg': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-26': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-6': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-40': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-53': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-71': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-68': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-35': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Hannover': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-31': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-47': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-51': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-59': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-61': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-70': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-79': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-10': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-5': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-7': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-8': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-12': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-17': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-18': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-19': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-21': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-22': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-27': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-29': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-32': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-33': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-36': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-38': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-44': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-45': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-46': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-49': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-50': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-52': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-56': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-60': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-65': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-67': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-73': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-78': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-80': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-81': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-43': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-48': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-75': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-84': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-Trier': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-42': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-16': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-15': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-25': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-82': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-28': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-23': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-34': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-37': {'measured': 'census', 'year': '1987'},
#  'cty-Germany-39': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-62': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-83': {'measured': 'census', 'year': '2011'},
#  'cty-Hungary-6': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-10': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Bekescaba': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-4': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-5': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-9': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-7': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-3': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Eger': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Tatabanya': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Kaposvar': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-8': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Szolnok': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Szombathely': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Veszprem': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Zalaegerszeg': {'year': '1990', 'measured': 'census'},
#  'cty-Hungary-Budapest': {'year': '1990', 'measured': 'census'},
#  'cty-Italy-44': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-5': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-36': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-19': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-Milan': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-34': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-51': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-49': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-17': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-14': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-39': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-12': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-16': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-46': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-7': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-8': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-28': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-38': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-21': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-22': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-43': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-29': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-30': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-31': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-23': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-50': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-9': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-24': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-27': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-37': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-45': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-Rome': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-42': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-32': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-26': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-4': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-47': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-52': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-11': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-25': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-48': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-53': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-15': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-41': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-40': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-20': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-6': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-13': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-10': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-33': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-18': {'year': '1991', 'measured': 'census'},
#  'cty-Italy-35': {'year': '1991', 'measured': 'census'},
#  'cty-Liechtenstein-Vaduz': {'year': '2001', 'measured': 'admin.'},
#  'cty-Slovakia-Bratislava': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-2': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-3': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-4': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-5': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-6': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-7': {'year': '2001', 'measured': 'census'},
#  'cty-Slovakia-8': {'year': '2001', 'measured': 'census'},
#  'cty-Slovenia-Ljubljana': {'year': '1991', 'measured': 'census'},
#  'cty-Slovenia-Maribor': {'year': '1991', 'measured': 'census'},
#  'cty-Switzerland-3': {'year': '1990', 'measured': 'est.'},
#  'cty-Switzerland-5': {'year': '1990', 'measured': 'est.'},
#  'cty-Switzerland-10': {'year': '1991'},
#  'cty-Switzerland-4': {'year': '1990', 'measured': 'est.'},
#  'cty-Switzerland-9': {'year': '1991'},
#  'cty-Switzerland-8': {'year': '1991'},
#  'cty-Switzerland-Lugano': {'year': '2009', 'measured': 'admin.'},
#  'cty-Switzerland-6': {'year': '1990', 'measured': 'est.'},
#  'cty-Switzerland-2': {'year': '1990', 'measured': 'est.'},
#  'cty-Switzerland-7': {'year': '1991'},
#  'cty-Belarus-1': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-2': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-3': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-4': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-5': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-6': {'year': '1999', 'measured': 'census'},
#  'cty-Belarus-Minsk': {'year': '1987'},
#  'cty-Latvia-Riga': {'year': '1987'},
#  'cty-Lithuania-1': {'year': '1987'},
#  'cty-Lithuania-2': {'year': '2001', 'measured': 'census'},
#  'cty-Lithuania-3': {'year': '2001', 'measured': 'census'},
#  'cty-PL-5': {'year': '1990'},
#  'cty-PL-41': {'year': '1990'},
#  'cty-PL-28': {'year': '1990'},
#  'cty-PL-9': {'year': '1990'},
#  'cty-PL-21': {'year': '1990'},
#  'cty-PL-43': {'year': '1990'},
#  'cty-PL-35': {'year': '1990'},
#  'cty-PL-11': {'year': '1990'},
#  'cty-PL-37': {'year': '1990'},
#  'cty-PL-Gorzow-Wielkopolski': {'year': '1990'},
#  'cty-PL-3': {'year': '1990'},
#  'cty-PL-Krakow': {'year': '1990'},
#  'cty-PL-36': {'year': '1990'},
#  'cty-PL-Warsaw': {'year': '1990'},
#  'cty-PL-34': {'year': '1990'},
#  'cty-PL-17': {'year': '1990'},
#  'cty-PL-31': {'year': '1990'},
#  'cty-PL-26': {'year': '1990'},
#  'cty-PL-12': {'year': '1990'},
#  'cty-PL-7': {'year': '1990'},
#  'cty-PL-15': {'year': '1990'},
#  'cty-PL-10': {'year': '1990'},
#  'cty-PL-42': {'year': '1990'},
#  'cty-PL-13': {'year': '1990'},
#  'cty-PL-29': {'year': '1990'},
#  'cty-PL-16': {'year': '1990'},
#  'cty-PL-18': {'year': '1990'},
#  'cty-PL-20': {'year': '1990'},
#  'cty-PL-22': {'year': '1990'},
#  'cty-PL-24': {'year': '1990'},
#  'cty-PL-27': {'year': '1990'},
#  'cty-PL-30': {'year': '1990'},
#  'cty-PL-14': {'year': '1990'},
#  'cty-PL-33': {'year': '2002', 'measured': 'census'},
#  'cty-PL-19': {'year': '1990'},
#  'cty-PL-25': {'year': '1990'},
#  'cty-PL-32': {'year': '1990'},
#  'cty-PL-6': {'year': '1990'},
#  'cty-PL-40': {'year': '1990'},
#  'cty-PL-8': {'year': '1990'},
#  'cty-PL-39': {'year': '1990'},
#  'cty-Ukraine-21': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-20': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-26': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-4': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-9': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-24': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Nikopol': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-5': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-10': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-13': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-18': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Kramatorsk': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-30': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Kharkiv': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-16': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-27': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Prypjat': {'year': '1970'},
#  'cty-Ukraine-25': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-12': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-8': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-11': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Odesa': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-19': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-28': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-29': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-23': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-31': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-14': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-32': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Uzhhorod': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-7': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Melitopol': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-22': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-17': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Kerch': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-Kiev': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-BilaTserkva': {'year': '1989', 'measured': 'census'},
#  'cty-Ukraine-15': {'year': '1989', 'measured': 'census'},
#  'cty-Russia-71': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-85': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-161': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-163': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-Arkhangelsk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-80': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-66': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-62': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-47': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Kaliningrad': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-3': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-83': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-90': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-40': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-57': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-110': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-133': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-36': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-55': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-155': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-70': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Moscow': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-94': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-98': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Krasnogorsk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-106': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-116': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-117': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-118': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-121': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-124': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-127': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-130': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-134': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-140': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-157': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-146': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Koroljow': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Zhukovsky': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Pushkino': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-54': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-28': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-52': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-41': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-31': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-119': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-23': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-79': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-78': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-61': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-42': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-136': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-39': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-4': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-69': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-147': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-59': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-95': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-15': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-43': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-37': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-139': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-63': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Elista': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-11': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-32': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-88': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-122': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-35': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Volgograd': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-68': {'measured': 'census', 'year': '1989'},
#  'cty-Russia-131': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-29': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-7': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-18': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-103': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-145': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-16': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-91': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-100': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-19': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-125': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-13': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Bataisk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-67': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-84': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-99': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-102': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-159': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-9': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-75': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-115': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-149': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-20': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-153': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-30': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-72': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-12': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-101': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-107': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-58': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Derbent': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Kaspijsk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Khasavyurt': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Nazran': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-81': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-141': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-64': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-50': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-21': {'year': '2002', 'measured': 'census'},
#  'cty-Russia-53': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-93': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-108': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-56': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-128': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-129': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-138': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Jessentuki': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-142': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-51': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-6': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-46': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-96': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-123': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-10': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-44': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-92': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-105': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Kopejsk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Gorno-Altaysk': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-25': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-86': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-104': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-33': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-27': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-77': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-5': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-8': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-38': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-150': {'measured': 'census', 'year': '2002'},
#  'cty-Russia-34': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-49': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Kyzyl': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-112': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Krasnoyarsk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-114': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-135': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-26': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-73': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-76': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-60': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-97': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Birobidzhan': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-Anadyr': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-Vladivostok': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-109': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-111': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-24': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-65': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-87': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-89': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-132': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-Okhotsk': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-113': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-KhantyMansijsk': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-74': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-82': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Neftejugansk': {'measured': 'census', 'year': '1979'},
#  'cty-Russia-Salekhard': {'year': '1979', 'measured': 'census'},
#  'cty-Russia-Njabrsk': {'measured': 'census', 'year': '2002'},
#  'cty-Russia-NovyUrengoy': {'measured': 'census', 'year': '2002'},
#  'cty-Belgium-Brussels': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-Schaarbeek': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-Molenbeek': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-Anderlecht': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-3-0': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-4-0': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-5-0': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-Mons': {'year': '1987'},
#  'cty-Belgium-6-0': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-Hasselt': {'year': '1987'},
#  'cty-Belgium-Arlon': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-8-0': {'year': '1990', 'measured': 'admin.'},
#  'cty-Belgium-7-0': {'year': '1987'},
#  'cty-Belgium-Leuven': {'year': '1990', 'measured': 'admin.'},
#  'cty-Luxembourg-Luxembourg': {'year': '1987'},
#  'cty-Netherlands-14': {'year': '1995'},
#  'cty-Netherlands-Leeuwarden': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-9': {'year': '1995'},
#  'cty-Netherlands-Zwolle': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-Lelystad': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-Almere': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-7': {'year': '1995'},
#  'cty-Netherlands-10': {'year': '1995'},
#  'cty-Netherlands-Apeldoorn': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-5': {'year': '1995'},
#  'cty-Netherlands-Amersfoort': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-Amsterdam': {'year': '1995'},
#  'cty-Netherlands-13': {'year': '1995'},
#  'cty-Netherlands-20': {'year': '2004', 'measured': 'admin.'},
#  'cty-Netherlands-22': {'year': '1995'},
#  'cty-Netherlands-4': {'year': '1995'},
#  'cty-Netherlands-3': {'year': '1995'},
#  'cty-Netherlands-12': {'year': '1995'},
#  'cty-Netherlands-16': {'year': '1995'},
#  'cty-Netherlands-15': {'year': '1995'},
#  'cty-Netherlands-6': {'year': '1995'},
#  'cty-Netherlands-11': {'year': '1995'},
#  'cty-Netherlands-18': {'year': '1995'},
#  'cty-Netherlands-19': {'year': '1995'},
#  'cty-Netherlands-8': {'year': '1995'},
#  'cty-Netherlands-17': {'year': '1995'},
#  'cty-BIH-1': {'year': '1991', 'measured': 'estimate'},
#  'cty-BIH-4': {'year': '1991', 'measured': 'estimate'},
#  'cty-BIH-5': {'year': '1991', 'measured': 'estimate'},
#  'cty-BIH-6': {'year': '1991', 'measured': 'estimate'},
#  'cty-BIH-2': {'year': '1991', 'measured': 'estimate'},
#  'cty-BIH-7': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-3': {'year': '1991'},
#  'cty-Croatia-1': {'year': '1991', 'measured': 'census'},
#  'cty-Croatia-2': {'year': '1991', 'measured': 'census'},
#  'cty-Croatia-3': {'year': '1991', 'measured': 'census'},
#  'cty-Croatia-4': {'year': '1991', 'measured': 'census'},
#  'cty-Croatia-5': {'year': '1991', 'measured': 'census'},
#  'cty-Bulgaria-1': {'year': '1987'},
#  'cty-Bulgaria-2': {'year': '2001', 'measured': 'census'},
#  'cty-Bulgaria-3': {'year': '2001', 'measured': 'census'},
#  'cty-Bulgaria-4': {'year': '2001', 'measured': 'census'},
#  'cty-Bulgaria-5': {'year': '2001', 'measured': 'census'},
#  'cty-Bulgaria-6': {'year': '2001', 'measured': 'census'},
#  'cty-Romania-12': {'year': '1989'},
#  'cty-Romania-16': {'year': '1989'},
#  'cty-Romania-13': {'year': '1989'},
#  'cty-Romania-11': {'year': '1989'},
#  'cty-Romania-Botosani': {'year': '2002', 'measured': 'census'},
#  'cty-Romania-10': {'year': '1989'},
#  'cty-Romania-3': {'year': '1989'},
#  'cty-Romania-2': {'year': '1989'},
#  'cty-Romania-18': {'year': '1989'},
#  'cty-Romania-7': {'year': '1989'},
#  'cty-Romania-4': {'year': '1989'},
#  'cty-Romania-9': {'year': '1989'},
#  'cty-Romania-8': {'year': '1989'},
#  'cty-Romania-6': {'year': '1989'},
#  'cty-Romania-17': {'year': '1989'},
#  'cty-Romania-Drobeta-Turnu-Severin': {'year': '2002', 'measured': 'census'},
#  'cty-Romania-15': {'year': '1989'},
#  'cty-Romania-Piatra-Neamt': {'year': '2002', 'measured': 'census'},
#  'cty-Romania-Ploiesti': {'year': '2002', 'measured': 'census'},
#  'cty-Romania-19': {'year': '1989'},
#  'cty-Romania-14': {'year': '1989'},
#  'cty-Romania-Suceava': {'year': '2002', 'measured': 'census'},
#  'cty-Romania-5': {'year': '1989'},
#  'cty-Romania-Ramnicu-Valcea': {'year': '2002', 'measured': 'census'},
#  'cty-Turkey-Adana': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-40': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Afyonkarahisar': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Agri': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Aksaray': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Amasya': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Ankara': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-10': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-42': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-28': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-31': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Bingol': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Bolu': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-6': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Inegol': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Canakkale': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Corum': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-24': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-13': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-45': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-26': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Erzincan': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-20': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-12': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-7': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Giresun': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-33': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-37': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-9': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-25': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-39': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Istanbul': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Izmir': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Karaman': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-21': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Kars': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Kastamonu': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-11': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-32': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Luleburgaz': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Kirsehir': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-18': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-23': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-8': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-35': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-17': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-29': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Mardin': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Kiziltepe': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Mus': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Nevsehir': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Nigde': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-41': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Rize': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-30': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-16': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-15': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Siirt': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-22': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Tekirdag': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Corlu': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Tokat': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-34': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-43': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-27': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Yozgat': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-44': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Karabuk': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Igdir': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Yalova': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Kilis': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Duzce': {'year': '1990', 'measured': 'census'},
#  'cty-Turkey-Osmaniye': {'year': '1990', 'measured': 'census'},
#  'stadt-Aalborg-DK-DK': {'year': '1987'},
#  'stadt-Aarhus-DK-DK': {'year': '1987'},
#  'stadt-Randers-DK-DK': {'year': '1987'},
#  'stadt-Vejle-DK-DK': {'year': '2001', 'measured': 'admin.'},
#  'stadt-Odense-DK-DK': {'year': '1987'},
#  'stadt-Esbjerg-DK-DK': {'year': '1987'},
#  'cty-Denmark-Copenhagen': {'year': '1987'},
#  'cty-Estonia-Tallinn': {'year': '1987'},
#  'cty-Estonia-Tartu': {'year': '2000', 'measured': 'census'},
#  'cty-Faroe-Islands-Torshavn': {'year': '2009', 'measured': 'admin.'},
#  'stadt-Mariehamn-SF-ALA': {'year': '1987'},
#  'stadt-Tampere-SF-HAE': {'year': '1987'},
#  'stadt-Lahti-SF-HAE': {'year': '1987'},
#  'stadt-Haemeenlinna-SF-HAE': {'year': '1987'},
#  'stadt-Kuopio-SF-KUO': {'year': '1987'},
#  'stadt-Lappeenranta-SF-KYM': {'year': '1987'},
#  'stadt-Kotka-SF-KYM': {'year': '1987'},
#  'stadt-Rovaniemi-SF-LAP': {'year': '1987'},
#  'stadt-Mikkeli-SF-MIK': {'year': '1987'},
#  'stadt-Jyvaeskylae-SF-MFI': {'year': '1987'},
#  'stadt-Joensuu-SF-NKA': {'year': '1987'},
#  'stadt-Oulu-SF-OUL': {'year': '1987'},
#  'stadt-Pori-SF-TUP': {'year': '1987'},
#  'stadt-Turku-SF-TUP': {'year': '1987'},
#  'cty-Finland-Helsinki': {'year': '1987'},
#  'stadt-Espoo-SF-UUS': {'year': '1987'},
#  'stadt-Vaasa-SF-VAA': {'year': '1987'},
#  'cty-Norway-Oslo': {'year': '1987'},
#  'cty-N-Sandvika': {'year': '2005', 'measured': 'admin.'},
#  'stadt-Moss-N-OES': {'year': '1987'},
#  'stadt-Hamar-N-HE': {'year': '1987'},
#  'stadt-Lillehammer-N-OP': {'year': '1987'},
#  'stadt-Drammen-N-BU': {'year': '1987'},
#  'stadt-Tonsberg-N-VE': {'year': '1987'},
#  'stadt-Skien-N-TE': {'year': '1987'},
#  'stadt-Arendal-N-AA': {'year': '1987'},
#  'stadt-Kristiansand-N-VA': {'year': '1987'},
#  'stadt-Stavanger-N-RO': {'year': '1987'},
#  'stadt-Bergen-N-HO': {'year': '1987'},
#  'stadt-Hermannsverk-N-SF': {'year': '1987'},
#  'stadt-Molde-N-MR': {'year': '1987'},
#  'stadt-Trondheim-N-ST': {'year': '1987'},
#  'stadt-Steinkjer-N-NT': {'year': '1987'},
#  'stadt-Svolvaer-N-NO': {'year': '1987'},
#  'stadt-Narvik-N-NO': {'year': '1987'},
#  'stadt-Bodoe-N-NO': {'year': '1987'},
#  'stadt-Tromsoe-N-TR': {'year': '1987'},
#  'stadt-Hammerfest-N-FI': {'year': '1987'},
#  'stadt-Vadsoe-N-FI': {'year': '1987'},
#  'cty-Sweden-3': {'year': '1987'},
#  'cty-Sweden-Vanersborg': {'year': '1987'},
#  'cty-Sweden-Mariestad': {'year': '1987'},
#  'cty-Sweden-Boras': {'year': '2002', 'measured': 'admin.'},
#  'cty-Sweden-Karlskrona': {'year': '1987'},
#  'cty-Sweden-Gavle': {'year': '1987'},
#  'cty-Sweden-Visby': {'year': '1987'},
#  'cty-Sweden-Halmstad': {'year': '1987'},
#  'cty-Sweden-Ostersund': {'year': '1987'},
#  'cty-Sweden-10': {'year': '1995'},
#  'cty-Sweden-Kalmar': {'year': '1987'},
#  'cty-Sweden-Falun': {'year': '1987'},
#  'cty-Sweden-4': {'year': '1995'},
#  'cty-Sweden-11': {'year': '1995'},
#  'cty-Sweden-Kristianstad': {'year': '1987'},
#  'cty-Sweden-Lund': {'year': '2002', 'measured': 'admin.'},
#  'cty-Sweden-Vaxjo': {'year': '1987'},
#  'cty-Sweden-Lulea': {'year': '1987'},
#  'stadt-Jokkmokk-S-BD': {'year': '1987'},
#  'cty-Sweden-9': {'year': '1995'},
#  'cty-Sweden-6': {'year': '1995'},
#  'cty-Sweden-7': {'year': '1995'},
#  'cty-Sweden-Nykoping': {'year': '1987'},
#  'cty-Sweden-Eskilstuna': {'year': '2002', 'measured': 'admin.'},
#  'cty-Sweden-Stockholm': {'year': '1995'},
#  'cty-Sweden-Huddinge': {'year': '2002', 'measured': 'admin.'},
#  'cty-Sweden-5': {'year': '1995'},
#  'cty-Sweden-Karlstad': {'year': '1987'},
#  'cty-Sweden-Umea': {'year': '1987'},
#  'cty-Sweden-Harnosand': {'year': '1987'},
#  'cty-Sweden-8': {'year': '1995'},
#  'cty-Monaco-Monaco': {'year': '1987'},
#  'cty-Holy-See-Vatican-City': {'year': '1997'},
#  'cty-Ceuta-Ceuta': {'year': '1960', 'measured': 'census'},
#  'cty-Melilla-Melilla': {'year': '1960', 'measured': 'census'},
#  'cty-Iceland-Reykjavik': {'year': '1987'},
#  'stadt-Keflavik-IS-IS': {'year': '1987'},
#  'stadt-Hafnarfjoerdur-IS-IS': {'year': '1987'},
#  'stadt-Akureyri-IS-IS': {'year': '1987'},
#  'cty-Ireland-Dublin': {'year': '2002', 'measured': 'census'},
#  'cty-IRL-2': {'year': '2002', 'measured': 'census'},
#  'cty-IRL-3': {'year': '2002', 'measured': 'census'},
#  'cty-IRL-': {'year': '2002', 'measured': 'census'},
#  'cty-San-Marino-San-Marino': {'year': '2000', 'measured': 'admin.'},
#  'cty-Malta-Valletta': {'year': '1995', 'measured': 'census'},
#  'cty-Malta-Victoria': {'year': '1995', 'measured': 'census'},
#  'cty-Moldova-Chisinau': {'year': '1987'},
#  'cty-Moldova-Tiraspol': {'year': '2004', 'measured': 'census'},
#  'cty-Moldova-Balti': {'year': '2004', 'measured': 'census'},
#  'cty-Portugal-Aveiro': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-7': {'year': '1981'},
#  'cty-Portugal-6': {'year': '1981'},
#  'cty-Portugal-Leiria': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-Lisbon': {'year': '1981'},
#  'cty-Portugal-4': {'year': '1981'},
#  'cty-Portugal-9': {'year': '1981'},
#  'cty-Portugal-11': {'year': '1981'},
#  'cty-Portugal-3': {'year': '1981'},
#  'cty-Portugal-8': {'year': '1981'},
#  'cty-Portugal-5': {'year': '1981'},
#  'cty-Portugal-PontaDelgada': {'year': '2002'},
#  'cty-Portugal-10': {'year': '1981'},
#  'cty-United-Kingdom-Newcastle': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-22': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-41': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-72': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-8': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-14': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-23': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-26': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-33': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-37': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-40': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-49': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-64': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-75': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-7': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-11': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-52': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-84': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-4': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-12': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-6': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-10': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-5': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-20': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-29': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-120': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-28': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-25': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-48': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Leicester': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-34': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Lincoln': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-3': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-15': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-32': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-42': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-31': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Worcester': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Sutton': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Telford': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-104': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-59': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-103': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-60': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Watford': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-55': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-56': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-67': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-87': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-53': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-2': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-39': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-47': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-70': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-50': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-57': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-63': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-76': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-85': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-77': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-121': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Eastbourne': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Gillingham': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Crawley': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Worthing': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Woking': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-9': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-30': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-116': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-58': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-79': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-113': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Gloucester': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-Swindon': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-134': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-133': {'measured': 'census', 'year': '2001'},
#  'cty-United-Kingdom-135': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-136': {'measured': 'census', 'year': '2001'},
#  'cty-United-Kingdom-Kirkwall': {'year': '2004'},
#  'cty-United-Kingdom-Lerwick': {'year': '2004'},
#  'cty-United-Kingdom-16': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-46': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-80': {'measured': 'census', 'year': '1991'},
#  'cty-United-Kingdom-17': {'measured': 'census', 'year': '1991'},
#  'cty-Afghanistan-Kabul': {'year': '1987'},
#  'cty-Afghanistan-2': {'year': '2004', 'measured': 'estimate'},
#  'cty-Afghanistan-3': {'year': '2004', 'measured': 'estimate'},
#  'cty-Afghanistan-4': {'year': '2004', 'measured': 'estimate'},
#  'cty-China-42': {'year': '1990', 'measured': 'census'},
#  'cty-China-34': {'year': '1991'},
#  'cty-China-73': {'year': '1990'},
#  'cty-China-76': {'year': '1990'},
#  'cty-China-94': {'year': '1990'},
#  'cty-China-120': {'year': '1990'},
#  'cty-China-147': {'year': '1990'},
#  'cty-China-159': {'year': '1990'},
#  'cty-China-213': {'year': '1990'},
#  'cty-China-257': {'year': '1990'},
#  'cty-China-292': {'year': '1990'},
#  'cty-China-295': {'year': '1990'},
#  'cty-China-311': {'year': '1990'},
#  'cty-China-45': {'year': '1990', 'measured': 'census'},
#  'cty-China-92': {'year': '1990', 'measured': 'census'},
#  'cty-China-187': {'year': '1990'},
#  'cty-China-202': {'year': '1990'},
#  'cty-China-207': {'year': '1990'},
#  'cty-China-237': {'year': '1990'},
#  'cty-China-269': {'year': '1990'},
#  'cty-China-314': {'year': '1990'},
#  'cty-China-23': {'year': '1990', 'measured': 'census'},
#  'cty-China-151': {'year': '1990'},
#  'cty-China-180': {'year': '1990'},
#  'cty-China-275': {'year': '1990'},
#  'cty-China-318': {'year': '1990'},
#  'cty-China-8': {'year': '1990', 'measured': 'census'},
#  'cty-China-56': {'year': '1990', 'measured': 'census'},
#  'cty-China-86': {'year': '1990'},
#  'cty-China-105': {'year': '1990', 'measured': 'census'},
#  'cty-China-108': {'year': '1990'},
#  'cty-China-117': {'year': '1990'},
#  'cty-China-119': {'year': '1990'},
#  'cty-China-121': {'year': '1990', 'measured': 'census'},
#  'cty-China-134': {'year': '1990'},
#  'cty-China-158': {'year': '1990'},
#  'cty-China-168': {'year': '1990'},
#  'cty-China-188': {'year': '1990'},
#  'cty-China-214': {'year': '1990'},
#  'cty-China-228': {'year': '1990'},
#  'cty-China-236': {'year': '1990', 'measured': 'census'},
#  'cty-China-280': {'year': '1990'},
#  'cty-China-301': {'year': '1990'},
#  'cty-China-321': {'year': '1990'},
#  'cty-China-21': {'year': '1990', 'measured': 'census'},
#  'cty-China-97': {'year': '1990'},
#  'cty-China-141': {'year': '1990'},
#  'cty-China-221': {'year': '1990'},
#  'cty-China-276': {'year': '1990'},
#  'cty-China-309': {'year': '1990'},
#  'cty-China-133': {'year': '1990'},
#  'cty-China-332': {'year': '1990'},
#  ...}

# %%
city_dict = {}

for element in document.iterfind('country'):
    for subelement in element.getiterator('city'):
        try:
            for sub_subelement in subelement.iterfind('population'):
                try:
                    city_dict.update({subelement.attrib['id'] : sub_subelement.attrib})
                except:
                    pass
        except:
            pass

city_dict
# Out:
# {'cty-Albania-Tirane': {'year': '2011', 'measured': 'census'},
#  'stadt-Shkoder-AL-AL': {'year': '2011', 'measured': 'census'},
#  'stadt-Durres-AL-AL': {'year': '2011', 'measured': 'census'},
#  'stadt-Vlore-AL-AL': {'year': '2011', 'measured': 'census'},
#  'stadt-Elbasan-AL-AL': {'year': '2011', 'measured': 'census'},
#  'stadt-Korce-AL-AL': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-9': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Athens': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-4': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Peristeri': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Acharnes': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-5': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Korfu': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Ioannina': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Thessaloniki': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-7': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Chania': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Rhodes': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Lamia': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Chalkida': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-6': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-8': {'year': '2011', 'measured': 'census'},
#  'cty-Greece-Karyes': {'year': '2014'},
#  'cty-Macedonia-Skopje': {'year': '2011', 'measured': 'estimate'},
#  'cty-Macedonia-Kumanovo': {'year': '2011', 'measured': 'estimate'},
#  'city-Belgrade-SRB-SRB': {'year': '2011', 'measured': 'census'},
#  'city-NoviSad-SRB-SRB': {'year': '2011', 'measured': 'census'},
#  'city-Nis-SRB-SRB': {'year': '2011', 'measured': 'census'},
#  'city-Podgorica-MNE-MNE': {'year': '2011', 'measured': 'census'},
#  'city-Pristina-KOS-KOS': {'year': '2011', 'measured': 'census'},
#  'cty-Andorra-Andorra-la-Vella': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Strasbourg': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-32': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-9': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-22': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-31': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-12': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-18': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-19': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-34': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-25': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-14': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Ajaccio': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-30': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-35': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-13': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Paris': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-36': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-38': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-39': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-40': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-10': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-26': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-33': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-23': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-28': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-37': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-5': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-15': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Nantes': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-21': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-20': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-24': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Poitiers': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-3': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Nice': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-16': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-27': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-Lyon': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-17': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-11': {'year': '2011', 'measured': 'admin.'},
#  'cty-France-29': {'year': '2011', 'measured': 'admin.'},
#  'cty-Spain-5': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-34': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-39': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-13': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-16': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-41': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-7': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-27': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-52': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-54': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-57': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-58': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-6': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-23': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-17': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-12': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-21': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-8': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-55': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-32': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-22': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-48': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-9': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-63': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-25': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-11': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-35': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-40': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-33': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-44': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-Barcelona': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-51': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-50': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-61': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-18': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-20': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-28': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-37': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-46': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-56': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-47': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-19': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-14': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-53': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-Madrid': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-24': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-31': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-36': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-38': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-42': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-43': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-59': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-60': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-62': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-10': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-30': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-29': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-49': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-Valencia': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-15': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-26': {'year': '2011', 'measured': 'census'},
#  'cty-Spain-45': {'year': '2011', 'measured': 'census'},
#  'cty-Austria-Eisenstadt': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-Klagenfurt': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-Villach': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-Vienna': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-4': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-Wels': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-6': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-3': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-5': {'year': '2013', 'measured': 'admin.'},
#  'cty-Austria-St-Polten': {'year': '2013', 'measured': 'admin.'},
#  'cty-Czech-2': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-8': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-3': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-Karlovy': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-Jihlava': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-9': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-11': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-4': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-5': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-10': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-7': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-Usti-nad-Labem': {'year': '2011', 'measured': 'estimate'},
#  'cty-Czech-6': {'year': '2011', 'measured': 'estimate'},
#  'cty-Germany-9': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-Mannheim': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-24': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-41': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-54': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-66': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-69': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-72': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-77': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-Munich': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-14': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-30': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-58': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-64': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-74': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-76': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-85': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-Berlin': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-55': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-63': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-11': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-57': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-Hamburg': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-26': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-6': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-40': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-53': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-71': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-68': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-35': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-Hannover': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-31': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-47': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-51': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-59': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-61': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-70': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-79': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-10': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-5': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-7': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-8': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-12': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-17': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-18': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-19': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-21': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-22': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-27': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-29': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-32': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-33': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-36': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-38': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-44': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-45': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-46': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-49': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-50': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-52': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-56': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-60': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-65': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-67': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-73': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-78': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-80': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-81': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-43': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-48': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-75': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-84': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-Trier': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-42': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-16': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-15': {'year': '2011', 'measured': 'census'},
#  'cty-Germany-25': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-82': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-28': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-23': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-34': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-37': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-39': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-62': {'measured': 'census', 'year': '2011'},
#  'cty-Germany-83': {'measured': 'census', 'year': '2011'},
#  'cty-Hungary-6': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-10': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Bekescaba': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-4': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-5': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-9': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-7': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-3': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Eger': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Tatabanya': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Kaposvar': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-8': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Szolnok': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Szombathely': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Veszprem': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Zalaegerszeg': {'year': '2011', 'measured': 'census'},
#  'cty-Hungary-Budapest': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-44': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-5': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-36': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-19': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-Milan': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-34': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-51': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-49': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-17': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-14': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-39': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-12': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-16': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-46': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-7': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-8': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-28': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-38': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-21': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-22': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-43': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-29': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-30': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-31': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-23': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-50': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-9': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-24': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-27': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-37': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-45': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-Rome': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-42': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-32': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-26': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-4': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-47': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-52': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-11': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-25': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-48': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-53': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-15': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-41': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-40': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-20': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-6': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-13': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-10': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-33': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-18': {'year': '2011', 'measured': 'census'},
#  'cty-Italy-35': {'year': '2011', 'measured': 'census'},
#  'cty-Liechtenstein-Vaduz': {'year': '2012', 'measured': 'admin.'},
#  'cty-Slovakia-Bratislava': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-2': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-3': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-4': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-5': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-6': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-7': {'year': '2011', 'measured': 'census'},
#  'cty-Slovakia-8': {'year': '2011', 'measured': 'census'},
#  'cty-Slovenia-Ljubljana': {'year': '2013', 'measured': 'admin.'},
#  'cty-Slovenia-Maribor': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-3': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-5': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-10': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-4': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-9': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-8': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-Lugano': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-6': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-2': {'year': '2013', 'measured': 'admin.'},
#  'cty-Switzerland-7': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belarus-1': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-2': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-3': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-4': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-5': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-6': {'year': '2009', 'measured': 'census'},
#  'cty-Belarus-Minsk': {'year': '2009', 'measured': 'census'},
#  'cty-Latvia-Riga': {'year': '2013', 'measured': 'estimate'},
#  'cty-Lithuania-1': {'year': '2013', 'measured': 'estimate'},
#  'cty-Lithuania-2': {'year': '2013', 'measured': 'estimate'},
#  'cty-Lithuania-3': {'year': '2013', 'measured': 'estimate'},
#  'cty-PL-5': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-41': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-28': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-9': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-21': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-43': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-35': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-11': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-37': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-Gorzow-Wielkopolski': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-3': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-Krakow': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-36': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-Warsaw': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-34': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-17': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-31': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-26': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-12': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-7': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-15': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-10': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-42': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-13': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-29': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-16': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-18': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-20': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-22': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-24': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-27': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-30': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-14': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-33': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-19': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-25': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-32': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-6': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-40': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-8': {'year': '2012', 'measured': 'estimate'},
#  'cty-PL-39': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-21': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-20': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-26': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-4': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-9': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-24': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Nikopol': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-5': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-10': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-13': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-18': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Kramatorsk': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-30': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Kharkiv': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-16': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-27': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Prypjat': {'year': '2001'},
#  'cty-Ukraine-25': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-12': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-8': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-11': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Odesa': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-19': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-28': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-29': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-23': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-31': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-14': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-32': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Uzhhorod': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-7': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Melitopol': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-22': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-17': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Kerch': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-Kiev': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-BilaTserkva': {'year': '2012', 'measured': 'estimate'},
#  'cty-Ukraine-15': {'year': '2012', 'measured': 'estimate'},
#  'cty-Russia-71': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-85': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-161': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-163': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-Arkhangelsk': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-80': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-66': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-62': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-47': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Kaliningrad': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-3': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-83': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-90': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-40': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-57': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-110': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-133': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-36': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-55': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-155': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-70': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Moscow': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-94': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-98': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Krasnogorsk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-106': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-116': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-117': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-118': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-121': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-124': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-127': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-130': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-134': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-140': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-157': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-146': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Koroljow': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Zhukovsky': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Pushkino': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-54': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-28': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-52': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-41': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-31': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-119': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-23': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-79': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-78': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-61': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-42': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-136': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-39': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-4': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-69': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-147': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-59': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-95': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-15': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-43': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-37': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-139': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-63': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Elista': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-11': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-32': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-88': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-122': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-35': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Volgograd': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-68': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-131': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-29': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-7': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-18': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-103': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-145': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-16': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-91': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-100': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-19': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-125': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-13': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Bataisk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-67': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-84': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-99': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-102': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-159': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-9': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-75': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-115': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-149': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-20': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-153': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-30': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-72': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-12': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-101': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-107': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-58': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Derbent': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Kaspijsk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Khasavyurt': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Nazran': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-81': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-141': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-64': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-50': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-21': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-53': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-93': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-108': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-56': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-128': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-129': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-138': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Jessentuki': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-142': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-51': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-6': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-46': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-96': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-123': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-10': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-44': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-92': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-105': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Kopejsk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Gorno-Altaysk': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-25': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-86': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-104': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-33': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-27': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-77': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-5': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-8': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-38': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-150': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-34': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-49': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Kyzyl': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-112': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Krasnoyarsk': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-114': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-135': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-26': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-73': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-76': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-60': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-97': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Birobidzhan': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-Anadyr': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-Vladivostok': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-109': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-111': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-24': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-65': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-87': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-89': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-132': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-Okhotsk': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-113': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-KhantyMansijsk': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-74': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-82': {'year': '2013', 'measured': 'estimate'},
#  'cty-Russia-Neftejugansk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-Salekhard': {'year': '2010', 'measured': 'census'},
#  'cty-Russia-Njabrsk': {'measured': 'census', 'year': '2010'},
#  'cty-Russia-NovyUrengoy': {'measured': 'census', 'year': '2010'},
#  'cty-Belgium-Brussels': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Schaarbeek': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Molenbeek': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Anderlecht': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-3-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-4-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-5-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Mons': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-6-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Hasselt': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Arlon': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-8-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-7-0': {'year': '2013', 'measured': 'admin.'},
#  'cty-Belgium-Leuven': {'year': '2013', 'measured': 'admin.'},
#  'cty-Luxembourg-Luxembourg': {'year': '2012', 'measured': 'admin.'},
#  'cty-Netherlands-14': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Leeuwarden': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-9': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Zwolle': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Lelystad': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Almere': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-7': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-10': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Apeldoorn': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-5': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Amersfoort': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-Amsterdam': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-13': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-20': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-22': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-4': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-3': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-12': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-16': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-15': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-6': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-11': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-18': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-19': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-8': {'year': '2014', 'measured': 'estimate'},
#  'cty-Netherlands-17': {'year': '2014', 'measured': 'estimate'},
#  'cty-BIH-1': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-4': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-5': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-6': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-2': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-7': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-BIH-3': {'year': '2013', 'measured': 'prelim. census'},
#  'cty-Croatia-1': {'year': '2011', 'measured': 'census'},
#  'cty-Croatia-2': {'year': '2011', 'measured': 'census'},
#  'cty-Croatia-3': {'year': '2011', 'measured': 'census'},
#  'cty-Croatia-4': {'year': '2011', 'measured': 'census'},
#  'cty-Croatia-5': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-1': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-2': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-3': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-4': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-5': {'year': '2011', 'measured': 'census'},
#  'cty-Bulgaria-6': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-12': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-16': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-13': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-11': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Botosani': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-10': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-3': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-2': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-18': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-7': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-4': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-9': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-8': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-6': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-17': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Drobeta-Turnu-Severin': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-15': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Piatra-Neamt': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Ploiesti': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-19': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-14': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Suceava': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-5': {'year': '2011', 'measured': 'census'},
#  'cty-Romania-Ramnicu-Valcea': {'year': '2011', 'measured': 'census'},
#  'cty-Turkey-Adana': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-40': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Afyonkarahisar': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Agri': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Aksaray': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Amasya': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Ankara': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-10': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-42': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-28': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-31': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Bingol': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Bolu': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-6': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Inegol': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Canakkale': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Corum': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-24': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-13': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-45': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-26': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Erzincan': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-20': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-12': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-7': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Giresun': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-33': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-37': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-9': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-25': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-39': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Istanbul': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Izmir': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Karaman': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-21': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Kars': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Kastamonu': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-11': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-32': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Luleburgaz': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Kirsehir': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-18': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-23': {'year': '2010', 'measured': 'admin.'},
#  'cty-Turkey-8': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-35': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-17': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-29': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Mardin': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Kiziltepe': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Mus': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Nevsehir': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Nigde': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-41': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Rize': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-30': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-16': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-15': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Siirt': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-22': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Tekirdag': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Corlu': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Tokat': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-34': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-43': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-27': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Yozgat': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-44': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Karabuk': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Igdir': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Yalova': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Kilis': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Duzce': {'year': '2012', 'measured': 'admin.'},
#  'cty-Turkey-Osmaniye': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Aalborg-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Aarhus-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Randers-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Vejle-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Odense-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'stadt-Esbjerg-DK-DK': {'year': '2012', 'measured': 'admin.'},
#  'cty-Denmark-Copenhagen': {'year': '2012', 'measured': 'admin.'},
#  'cty-Estonia-Tallinn': {'year': '2010', 'measured': 'estimate'},
#  'cty-Estonia-Tartu': {'year': '2010', 'measured': 'estimate'},
#  'cty-Faroe-Islands-Torshavn': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Mariehamn-SF-ALA': {'year': '2007', 'measured': 'admin.'},
#  'stadt-Tampere-SF-HAE': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Lahti-SF-HAE': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Haemeenlinna-SF-HAE': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Kuopio-SF-KUO': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Lappeenranta-SF-KYM': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Kotka-SF-KYM': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Rovaniemi-SF-LAP': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Mikkeli-SF-MIK': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Jyvaeskylae-SF-MFI': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Joensuu-SF-NKA': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Oulu-SF-OUL': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Pori-SF-TUP': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Turku-SF-TUP': {'year': '2014', 'measured': 'admin.'},
#  'cty-Finland-Helsinki': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Espoo-SF-UUS': {'year': '2014', 'measured': 'admin.'},
#  'stadt-Vaasa-SF-VAA': {'year': '2014', 'measured': 'admin.'},
#  'cty-Norway-Oslo': {'year': '2013', 'measured': 'admin.'},
#  'cty-N-Sandvika': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Moss-N-OES': {'year': '1987'},
#  'stadt-Hamar-N-HE': {'year': '1987'},
#  'stadt-Lillehammer-N-OP': {'year': '1987'},
#  'stadt-Drammen-N-BU': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Tonsberg-N-VE': {'year': '1987'},
#  'stadt-Skien-N-TE': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Arendal-N-AA': {'year': '1987'},
#  'stadt-Kristiansand-N-VA': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Stavanger-N-RO': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Bergen-N-HO': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Hermannsverk-N-SF': {'year': '1987'},
#  'stadt-Molde-N-MR': {'year': '1987'},
#  'stadt-Trondheim-N-ST': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Steinkjer-N-NT': {'year': '1987'},
#  'stadt-Svolvaer-N-NO': {'year': '1987'},
#  'stadt-Narvik-N-NO': {'year': '1987'},
#  'stadt-Bodoe-N-NO': {'year': '1987'},
#  'stadt-Tromsoe-N-TR': {'year': '2013', 'measured': 'admin.'},
#  'stadt-Hammerfest-N-FI': {'year': '1987'},
#  'stadt-Vadsoe-N-FI': {'year': '1987'},
#  'cty-Sweden-3': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Vanersborg': {'year': '1987'},
#  'cty-Sweden-Mariestad': {'year': '1987'},
#  'cty-Sweden-Boras': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Karlskrona': {'year': '1987'},
#  'cty-Sweden-Gavle': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Visby': {'year': '1987'},
#  'cty-Sweden-Halmstad': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Ostersund': {'year': '1987'},
#  'cty-Sweden-10': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Kalmar': {'year': '1987'},
#  'cty-Sweden-Falun': {'year': '1987'},
#  'cty-Sweden-4': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-11': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Kristianstad': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Lund': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Vaxjo': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Lulea': {'year': '1987'},
#  'stadt-Jokkmokk-S-BD': {'year': '1987'},
#  'cty-Sweden-9': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-6': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-7': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Nykoping': {'year': '1987'},
#  'cty-Sweden-Eskilstuna': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Stockholm': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Huddinge': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-5': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Karlstad': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Umea': {'year': '2012', 'measured': 'admin.'},
#  'cty-Sweden-Harnosand': {'year': '1987'},
#  'cty-Sweden-8': {'year': '2012', 'measured': 'admin.'},
#  'cty-Monaco-Monaco': {'year': '2008', 'measured': 'census'},
#  'cty-Holy-See-Vatican-City': {'year': '2014'},
#  'cty-Ceuta-Ceuta': {'year': '2011', 'measured': 'census'},
#  'cty-Melilla-Melilla': {'year': '2011', 'measured': 'census'},
#  'cty-Iceland-Reykjavik': {'year': '2011', 'measured': 'admin.'},
#  'stadt-Keflavik-IS-IS': {'year': '2011', 'measured': 'admin.'},
#  'stadt-Hafnarfjoerdur-IS-IS': {'year': '2011', 'measured': 'admin.'},
#  'stadt-Akureyri-IS-IS': {'year': '2011', 'measured': 'admin.'},
#  'cty-Ireland-Dublin': {'year': '2011', 'measured': 'census'},
#  'cty-IRL-2': {'year': '2011', 'measured': 'census'},
#  'cty-IRL-3': {'year': '2011', 'measured': 'census'},
#  'cty-IRL-': {'year': '2011', 'measured': 'census'},
#  'cty-San-Marino-San-Marino': {'year': '2012', 'measured': 'admin.'},
#  'cty-Malta-Valletta': {'year': '2010', 'measured': 'census'},
#  'cty-Malta-Victoria': {'year': '2010', 'measured': 'census'},
#  'cty-Moldova-Chisinau': {'year': '2010', 'measured': 'estimate'},
#  'cty-Moldova-Tiraspol': {'year': '2010'},
#  'cty-Moldova-Balti': {'year': '2010', 'measured': 'estimate'},
#  'cty-Portugal-Aveiro': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-7': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-6': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-Leiria': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-Lisbon': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-4': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-9': {'year': '2011'},
#  'cty-Portugal-11': {'year': '2011'},
#  'cty-Portugal-3': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-8': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-5': {'year': '2001', 'measured': 'census'},
#  'cty-Portugal-PontaDelgada': {'year': '2002'},
#  'cty-Portugal-10': {'year': '2001', 'measured': 'census'},
#  'cty-United-Kingdom-Newcastle': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-22': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-41': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-72': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-8': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-14': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-23': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-26': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-33': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-37': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-40': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-49': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-64': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-75': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-7': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-11': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-52': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-84': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-4': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-12': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-6': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-10': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-5': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-20': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-29': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-120': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-28': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-25': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-48': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Leicester': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-34': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Lincoln': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-3': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-15': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-32': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-42': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-31': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Worcester': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Sutton': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Telford': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-104': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-59': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-103': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-60': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Watford': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-55': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-56': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-67': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-87': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-53': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-2': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-39': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-47': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-70': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-50': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-57': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-63': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-76': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-85': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-77': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-121': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Eastbourne': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Gillingham': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Crawley': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Worthing': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Woking': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-9': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-30': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-116': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-58': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-79': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-113': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Gloucester': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Swindon': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-134': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-133': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-135': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-136': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-Kirkwall': {'year': '2004'},
#  'cty-United-Kingdom-Lerwick': {'year': '2004'},
#  'cty-United-Kingdom-16': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-46': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-80': {'measured': 'census', 'year': '2011'},
#  'cty-United-Kingdom-17': {'measured': 'census', 'year': '2011'},
#  'cty-Afghanistan-Kabul': {'year': '2004', 'measured': 'estimate'},
#  'cty-Afghanistan-2': {'year': '2004', 'measured': 'estimate'},
#  'cty-Afghanistan-3': {'year': '2004', 'measured': 'estimate'},
#  'cty-Afghanistan-4': {'year': '2004', 'measured': 'estimate'},
#  'cty-China-42': {'year': '2010', 'measured': 'census'},
#  'cty-China-34': {'year': '1991'},
#  'cty-China-73': {'year': '1990'},
#  'cty-China-76': {'year': '1990'},
#  'cty-China-94': {'year': '1990'},
#  'cty-China-120': {'year': '1990'},
#  'cty-China-147': {'year': '1990'},
#  'cty-China-159': {'year': '1990'},
#  'cty-China-213': {'year': '1990'},
#  'cty-China-257': {'year': '1990'},
#  'cty-China-292': {'year': '1990'},
#  'cty-China-295': {'year': '1990'},
#  'cty-China-311': {'year': '1990'},
#  'cty-China-45': {'year': '2010', 'measured': 'census'},
#  'cty-China-92': {'year': '2010', 'measured': 'census'},
#  'cty-China-187': {'year': '1990'},
#  'cty-China-202': {'year': '1990'},
#  'cty-China-207': {'year': '1990'},
#  'cty-China-237': {'year': '1990'},
#  'cty-China-269': {'year': '1990'},
#  'cty-China-314': {'year': '1990'},
#  'cty-China-23': {'year': '2010', 'measured': 'census'},
#  'cty-China-151': {'year': '1990'},
#  'cty-China-180': {'year': '1990'},
#  'cty-China-275': {'year': '1990'},
#  'cty-China-318': {'year': '1990'},
#  'cty-China-8': {'year': '2010', 'measured': 'census'},
#  'cty-China-56': {'year': '2010', 'measured': 'census'},
#  'cty-China-86': {'year': '1990'},
#  'cty-China-105': {'year': '2010', 'measured': 'census'},
#  'cty-China-108': {'year': '1990'},
#  'cty-China-117': {'year': '1990'},
#  'cty-China-119': {'year': '2010', 'measured': 'census'},
#  'cty-China-121': {'year': '2010', 'measured': 'census'},
#  'cty-China-134': {'year': '2010', 'measured': 'census'},
#  'cty-China-158': {'year': '1990'},
#  'cty-China-168': {'year': '1990'},
#  'cty-China-188': {'year': '1990'},
#  'cty-China-214': {'year': '1990'},
#  'cty-China-228': {'year': '1990'},
#  'cty-China-236': {'year': '2010', 'measured': 'census'},
#  'cty-China-280': {'year': '1990'},
#  'cty-China-301': {'year': '1990'},
#  'cty-China-321': {'year': '1990'},
#  'cty-China-21': {'year': '2010', 'measured': 'census'},
#  'cty-China-97': {'year': '1990'},
#  'cty-China-141': {'year': '1990'},
#  'cty-China-221': {'year': '1990'},
#  'cty-China-276': {'year': '1990'},
#  'cty-China-309': {'year': '1990'},
#  'cty-China-133': {'year': '1990'},
#  'cty-China-332': {'year': '1990'},
#  ...}

# %% [markdown]
#     <city id="cty-Albania-Tirane" country="AL">
#              <name>Tirana</name>
#              <name>Tirane</name>
#              <latitude>41.3</latitude>
#              <longitude>19.8</longitude>
#              <population year="1987">192000</population>
#              <population year="1990" measured="estimate">244153</population>
#              <population year="2011" measured="census">418495</population>
#           </city>
#           <city id="stadt-Shkoder-AL-AL" country="AL">
#              <name>Shkodër</name>
#              <latitude>42.2</latitude>
#              <longitude>19.2</longitude>
#              <population year="1987">62000</population>
#              <population year="2011" measured="census">77075</population>
#              <located_at watertype="lake" lake="lake-Skutarisee"/>
#           </city>

# %%
document.find('country').find('city').attrib['id']
# Out:
# 'cty-Albania-Tirane'

# %%
city_list = []
pop_list = []
for element in document.iterfind('country'):
    for subelement in element.getiterator('city'):
        try:
            city_list.append(subelement.find('name').text)
        except:
            pass
        
        try:
            pop_list.append(subelement.findall('population').attrib)
        except:
            pass
#        subelement.attrib

# %%
pop_list
# Out:
# []

# %%
city_list
# Out:
# ['Tirana',
#  'Shkodër',
#  'Durrës',
#  'Vlorë',
#  'Elbasan',
#  'Korçë',
#  'Komotini',
#  'Kavala',
#  'Athina',
#  'Peiraias',
#  'Peristeri',
#  'Acharnes',
#  'Patra',
#  'Kozani',
#  'Kerkyra',
#  'Ioannina',
#  'Thessaloniki',
#  'Iraklio',
#  'Chania',
#  'Ermoupoli',
#  'Rhodes',
#  'Tripoli',
#  'Lamia',
#  'Chalkida',
#  'Larissa',
#  'Volos',
#  'Mytilini',
#  'Karyes',
#  'Skopje',
#  'Kumanovo',
#  'Beograd',
#  'Novi Sad',
#  'Niš',
#  'Podgorica',
#  'Prishtine',
#  'Andorra la Vella',
#  'Strasbourg',
#  'Mulhouse',
#  'Bordeaux',
#  'Clermont-Ferrand',
#  'Caen',
#  'Rennes',
#  'Brest',
#  'Dijon',
#  'Orléans',
#  'Tours',
#  'Reims',
#  'Chalons en Champagne',
#  'Ajaccio',
#  'Besançon',
#  'Rouen',
#  'Le Havre',
#  'Paris',
#  'Boulogne-Billancourt',
#  'Argenteuil',
#  'Montreuil',
#  'Saint-Paul',
#  'Montpellier',
#  'Nîmes',
#  'Perpignan',
#  'Limoges',
#  'Metz',
#  'Nancy',
#  'Toulouse',
#  'Lille',
#  'Nantes',
#  'Angers',
#  'Le Mans',
#  'Amiens',
#  'Poitiers',
#  'Marseille',
#  'Nice',
#  'Toulon',
#  'Aix-en-Provence',
#  'Lyon',
#  'Grenoble',
#  'Saint-Étienne',
#  'Villeurbanne',
#  'Sevilla',
#  'Almería',
#  'Cádiz',
#  'Córdoba',
#  'Granada',
#  'Huelva',
#  'Málaga',
#  'Jerez de la Frontera',
#  'Jaén',
#  'Algeciras',
#  'Marbella',
#  'Dos Hermanas',
#  'Zaragoza',
#  'Oviedo',
#  'Gijón',
#  'Palma de Mallorca',
#  'Vitoria-Gasteiz',
#  'Bilbao',
#  'Barakaldo',
#  'Donostia',
#  'Santa Cruz de Tenerife',
#  'San Cristóbal de La Laguna',
#  'Las Palmas de Gran Canaria',
#  'Telde',
#  'Santander',
#  'Valladolid',
#  'Burgos',
#  'León',
#  'Salamanca',
#  'Toledo',
#  'Albacete',
#  'Barcelona',
#  'Lleida',
#  'Tarragona',
#  'Reus',
#  'Hospitalet de Llobregat',
#  'Badalona',
#  'Sabadell',
#  'Terrassa',
#  'Santa Coloma de Gramenet',
#  'Mataró',
#  'Badajoz',
#  'Merida',
#  'A Coruña',
#  'Vigo',
#  'Ourense',
#  'Santiago de Compostela',
#  'Madrid',
#  'Móstoles',
#  'Leganés',
#  'Alcalá de Henares',
#  'Fuenlabrada',
#  'Getafe',
#  'Alcorcón',
#  'Torrejón de Ardoz',
#  'Parla',
#  'Alcobendas',
#  'Murcia',
#  'Cartagena',
#  'Pamplona',
#  'Logroño',
#  'Valencia',
#  'Alicante',
#  'Elche',
#  'Castellón de la Plana',
#  'Eisenstadt',
#  'Klagenfurt',
#  'Villach',
#  'Bregenz',
#  'Wien',
#  'Linz',
#  'Wels',
#  'Innsbruck',
#  'Graz',
#  'Salzburg',
#  'St. Pölten',
#  'Praha',
#  'České Budějovice',
#  'Brno',
#  'Karlovy Vary',
#  'Jihlava',
#  'Hradec Králové',
#  'Liberec',
#  'Ostrava',
#  'Olomouc',
#  'Pardubice',
#  'Plzeň',
#  'Ústí nad Labem',
#  'Zlín',
#  'Stuttgart',
#  'Mannheim',
#  'Karlsruhe',
#  'Freiburg',
#  'Heidelberg',
#  'Heilbronn',
#  'Pforzheim',
#  'Ulm',
#  'Reutlingen',
#  'München',
#  'Nürnberg',
#  'Augsburg',
#  'Würzburg',
#  'Regensburg',
#  'Ingolstadt',
#  'Fürth',
#  'Erlangen',
#  'Berlin',
#  'Potsdam',
#  'Cottbus',
#  'Bremen',
#  'Bremerhaven',
#  'Hamburg',
#  'Wiesbaden',
#  'Frankfurt am Main',
#  'Kassel',
#  'Darmstadt',
#  'Offenbach am Main',
#  'Schwerin',
#  'Rostock',
#  'Hannover',
#  'Braunschweig',
#  'Osnabrück',
#  'Oldenburg',
#  'Göttingen',
#  'Wolfsburg',
#  'Salzgitter',
#  'Hildesheim',
#  'Düsseldorf',
#  'Köln',
#  'Essen',
#  'Dortmund',
#  'Duisburg',
#  'Bochum',
#  'Wuppertal',
#  'Bielefeld',
#  'Gelsenkirchen',
#  'Bonn',
#  'Mönchengladbach',
#  'Münster',
#  'Krefeld',
#  'Aachen',
#  'Oberhausen',
#  'Hagen',
#  'Hamm',
#  'Herne',
#  'Mülheim an der Ruhr',
#  'Solingen',
#  'Leverkusen',
#  'Neuss',
#  'Paderborn',
#  'Recklinghausen',
#  'Remscheid',
#  'Bottrop',
#  'Siegen',
#  'Moers',
#  'Witten',
#  'Bergisch Gladbach',
#  'Mainz',
#  'Ludwigshafen',
#  'Koblenz',
#  'Kaiserslautern',
#  'Trier',
#  'Saarbrücken',
#  'Dresden',
#  'Leipzig',
#  'Chemnitz',
#  'Zwickau',
#  'Magdeburg',
#  'Halle',
#  'Kiel',
#  'Lübeck',
#  'Erfurt',
#  'Gera',
#  'Jena',
#  'Pécs',
#  'Kecskemét',
#  'Békéscsaba',
#  'Miskolc',
#  'Szeged',
#  'Hodmezovasarhely',
#  'Székesfehérvár',
#  'Győr',
#  'Debrecen',
#  'Eger',
#  'Tatabánya',
#  'Salgotarjan',
#  'Kaposvár',
#  'Nyíregyháza',
#  'Szolnok',
#  'Szekszard',
#  'Szombathely',
#  'Veszprém',
#  'Zalaegerszeg',
#  'Budapest',
#  'Novara',
#  'Torino',
#  'Aosta',
#  'Bérgamo',
#  'Bréscia',
#  'Milano',
#  'Monza',
#  'Bolzano',
#  'Trento',
#  'Pádova',
#  'Verona',
#  'Vicenza',
#  'Venézia',
#  'Trieste',
#  'La Spezia',
#  'Génova',
#  'Bologna',
#  'Ferrara',
#  'Forlí',
#  'Módena',
#  'Parma',
#  'Piacenza',
#  'Ravenna',
#  "Réggio nell'Emilia",
#  'Rímini',
#  'Livorno',
#  'Pisa',
#  'Firenze',
#  'Prato',
#  'Perúgia',
#  'Terni',
#  'Ancona',
#  'Roma',
#  'Latina',
#  'Pescara',
#  'LAquila',
#  'Campobasso',
#  'Salerno',
#  'Nápoli',
#  'Torre del Greco',
#  'Giugliano in Campania',
#  'Bari',
#  'Fóggia',
#  'Lecce',
#  'Andria',
#  'Táranto',
#  'Potenza',
#  'Catanzaro',
#  'Cosenza',
#  'Réggio di Calabria',
#  'Palermo',
#  'Messina',
#  'Catánia',
#  'Siracusa',
#  'Cágliari',
#  'Sássari',
#  'Vaduz',
#  'Bratislava',
#  'Banská Bystrica',
#  'Žilina',
#  'Košice',
#  'Prešov',
#  'Nitra',
#  'Trenčín',
#  'Trnava',
#  'Ljubljana',
#  'Maribor',
#  'Aarau',
#  'Herisau',
#  'Appenzell',
#  'Liestal',
#  'Basel',
#  'Bern',
#  'Biel',
#  'Fribourg',
#  'Genève',
#  'Glarus',
#  'Chur',
#  'Delemont',
#  'Luzern',
#  'Neuchatel',
#  'Stans',
#  'Sarnen',
#  'Sankt Gallen',
#  'Schaffhausen',
#  'Schwyz',
#  'Solothurn',
#  'Frauenfeld',
#  'Bellinzona',
#  'Lugano',
#  'Altdorf',
#  'Sion',
#  'Lausanne',
#  'Zug',
#  'Zürich',
#  'Winterthur',
#  'Brest',
#  'Vitebsk',
#  'Gomel',
#  'Grodno',
#  'Mogilev',
#  'Bobruysk',
#  'Minsk',
#  'Rīga',
#  'Vilnius',
#  'Kaunas',
#  'Klaipeda',
#  'Wrocław',
#  'Legnica',
#  'Wałbrzych',
#  'Bydgoszcz',
#  'Toruń',
#  'Grudziadz',
#  'Włocławek',
#  'Lublin',
#  'Zielona Góra',
#  'Gorzów Wielkopolski',
#  'Łódź',
#  'Kraków',
#  'Tarnów',
#  'Warszawa',
#  'Płock',
#  'Radom',
#  'Opole',
#  'Rzeszów',
#  'Białystok',
#  'Gdańsk',
#  'Gdynia',
#  'Katowice',
#  'Jastrzebie Zdroj',
#  'Sosnowiec',
#  'Dąbrowa Górnicza',
#  'Bytom',
#  'Gliwice',
#  'Zabrze',
#  'Tychy',
#  'Ruda Śląska',
#  'Rybnik',
#  'Chorzów',
#  'Częstochowa',
#  'Bielsko-Biała',
#  'Kielce',
#  'Olsztyn',
#  'Elbląg',
#  'Poznań',
#  'Kalisz',
#  'Szczecin',
#  'Koszalin',
#  'Cherkasy',
#  'Chernihiv',
#  'Chernivtsi',
#  'Dnipropetrovs´k',
#  'Kryvyi Rih',
#  'Dniprodzerzhyns´k',
#  'Nikopol´',
#  'Donets´k',
#  'Mariupol´',
#  'Makiïvka',
#  'Horlivka',
#  'Kramators´k',
#  'Ivano-Frankivs´k',
#  'Kharkiv',
#  'Kherson',
#  'Khmel´nyts´kyi',
#  'Prypjat',
#  'Kirovohrad',
#  'Luhans´k',
#  'L´viv',
#  'Mykolaïv',
#  'Odesa',
#  'Poltava',
#  'Kremenchuk',
#  'Rivne',
#  'Sumy',
#  'Ternopil´',
#  'Vinnytsia',
#  'Luts´k',
#  'Uzhhorod',
#  'Zaporizhzhia',
#  'Melitopol´',
#  'Zhytomyr',
#  'Simferopol´',
#  'Kerch',
#  'Kyïv',
#  'Bila Tserkva',
#  'Sevastopol´',
#  'Petrozavodsk',
#  'Syktyvkar',
#  'Ukhta',
#  'Vorkuta',
#  'Arkhangelsk',
#  'Severodvinsk',
#  'Vologda',
#  'Cherepovets',
#  'Murmansk',
#  'Kaliningrad',
#  'Sankt Peterburg',
#  'Velikij Novgorod',
#  'Pskov',
#  'Bryansk',
#  'Vladimir',
#  'Kovrov',
#  'Murom',
#  'Ivanovo',
#  'Kaluga',
#  'Obninsk',
#  'Kostroma',
#  'Moskva',
#  "Podol'sk",
#  'Železnodorožnyj',
#  'Krasnogorsk',
#  "L'ubercy",
#  'Kolomna',
#  'Mytišči',
#  "Elektrostal'",
#  'Serpuchov',
#  'Balašicha',
#  'Chimki',
#  'Odincovo',
#  'Orechovo-Zujevo',
#  'Noginsk',
#  'Ščëlkovo',
#  'Sergijev Posad',
#  'Korolëv',
#  'Žukovskij',
#  'Puškino',
#  'Orel',
#  'Ryazan',
#  'Smolensk',
#  'Tver',
#  'Tula',
#  'Novomoskovsk',
#  'Yaroslavl',
#  'Rybinsk',
#  'Yoshkar-Ola',
#  'Saransk',
#  'Cheboksary',
#  'Novočeboksarsk',
#  'Kirov',
#  'Nizhnii Novgorod',
#  'Dzeržinsk',
#  'Arzamas',
#  'Belgorod',
#  'Staryj Oskol',
#  'Voronezh',
#  'Kursk',
#  'Lipetsk',
#  'Jelec',
#  'Tambov',
#  'Elista',
#  'Kazan',
#  'Naberezhnye Tchelny',
#  'Nižnekamsk',
#  "Al'metjevsk",
#  'Astrakhan',
#  'Volgograd',
#  'Volzhsky',
#  'Kamyšin',
#  'Penza',
#  'Samara',
#  'Tolyatti',
#  "Syzran'",
#  'Novokujbyševsk',
#  'Saratov',
#  'Balakovo',
#  "Ėngel's",
#  'Ulyanovsk',
#  'Dimitrovgrad',
#  'Rostov-na-Donu',
#  'Batajsk',
#  'Taganrog',
#  'Šachty',
#  'Novočerkassk',
#  'Volgodonsk',
#  'Novošachtinsk',
#  'Ufa',
#  'Sterlitamak',
#  'Salavat',
#  "Okt'abr'skij",
#  'Izhevsk',
#  'Sarapul',
#  'Orenburg',
#  'Orsk',
#  'Perm',
#  'Berezniki',
#  'Majkop',
#  'Makhachkala',
#  'Derbent',
#  'Kaspijsk',
#  'Chasavjurt',
#  "Nazran'",
#  "Nal'čik",
#  'Čerkessk',
#  'Vladikavkaz',
#  'Grozny',
#  'Krasnodar',
#  'Sochi',
#  'Novorossiysk',
#  'Armavir',
#  'Stavropol',
#  "P'atigorsk",
#  'Nevinnomyssk',
#  'Kislovodsk',
#  'Jessentuki',
#  'Neftekamsk',
#  'Kurgan',
#  'Yekaterinburg',
#  'Nizhny Tagil',
#  "Kamensk-Ural'skij",
#  "Pervoural'sk",
#  'Chelyabinsk',
#  'Magnitogorsk',
#  'Zlatoust',
#  'Miass',
#  'Kopejsk',
#  'Gorno Altaysk',
#  'Barnaul',
#  'Bijsk',
#  'Rubcovsk',
#  'Kemerovo',
#  'Novokuznetsk',
#  'Prokopjevsk',
#  'Novosibirsk',
#  'Omsk',
#  'Tomsk',
#  'Seversk',
#  'Tyumen',
#  'Ulan-Ude',
#  'Kyzyl',
#  'Abakan',
#  'Krasnoyarsk',
#  "Noril'sk",
#  'Ačinsk',
#  'Irkutsk',
#  'Angarsk',
#  'Bratsk',
#  'Chita',
#  'Yakutsk',
#  'Birobidzhan',
#  'Anadyr',
#  'Vladivostok',
#  'Nachodka',
#  'Ussurijsk',
#  'Khabarovsk',
#  'Komsomolsk-na-Amure',
#  'Blagoveščensk',
#  'Petropavlovsk-Kamčatskij',
#  'Magadan',
#  'Okhotsk',
#  'Južno-Sachalinsk',
#  'Khanty Mansijsk',
#  'Surgut',
#  'Nizhnevartovsk',
#  'Neftejugansk',
#  'Salekhard',
#  "Nojabr'sk",
#  'Novyj Urengoj',
#  'Bruxelles',
#  'Schaerbeek',
#  'Molenbeek-Saint-Jean',
#  'Anderlecht',
#  'Antwerpen',
#  'Gent',
#  'Charleroi',
#  'Mons',
#  'Liège',
#  'Hasselt',
#  'Arlon',
#  'Namur',
#  'Brugge',
#  'Wavre',
#  'Leuven',
#  'Luxembourg',
#  'Groningen',
#  'Leeuwarden',
#  'Assen',
#  'Enschede',
#  'Zwolle',
#  'Lelystad',
#  'Almere',
#  'Arnhem',
#  'Nijmegen',
#  'Apeldoorn',
#  'Utrecht',
#  'Amersfoort',
#  'Amsterdam',
#  'Haarlem',
#  'Zaanstad',
#  'Hilversum',
#  'Den Haag',
#  'Rotterdam',
#  'Dordrecht',
#  'Leiden',
#  'Middelburg',
#  "'s-Hertogenbosch",
#  'Eindhoven',
#  'Tilburg',
#  'Breda',
#  'Maastricht',
#  'Heerlen',
#  'Sittard-Geleen',
#  'Sarajevo',
#  'Tuzla',
#  'Zenica',
#  'Mostar',
#  'Banja Luka',
#  'Bijeljina',
#  'Brčko',
#  'Zagreb',
#  'Split',
#  'Rijeka',
#  'Osijek',
#  'Zadar',
#  'Sofia',
#  'Plovdiv',
#  'Varna',
#  'Burgas',
#  'Ruse',
#  'Stara Zagora',
#  'Alba Iulia',
#  'Arad',
#  'Piteşti',
#  'Bacău',
#  'Oradea',
#  'Bistrita',
#  'Botoşani',
#  'Brăila',
#  'Braşov',
#  'Bucureşti',
#  'Buzău',
#  'Calarasi',
#  'Resita',
#  'Cluj-Napoca',
#  'Constanţa',
#  'Sfintu Gheorghe',
#  'Targoviste',
#  'Craiova',
#  'Galaţi',
#  'Giurgiu',
#  'Tirgu Jiu',
#  'Miercurea Ciuc',
#  'Deva',
#  'Slobozia',
#  'Iaşi',
#  'Baia Mare',
#  'Drobeta-Turnu Severin',
#  'Târgu Mureş',
#  'Piatra-Neamţ',
#  'Slatina',
#  'Ploieşti',
#  'Zalau',
#  'Satu Mare',
#  'Sibiu',
#  'Suceava',
#  'Alexandria',
#  'Timişoara',
#  'Tulcea',
#  'Vaslui',
#  'Râmnicu Vâlcea',
#  'Focsani',
#  'Adana',
#  'Adiyaman',
#  'Afyonkarahisar',
#  'Agri',
#  'Aksaray',
#  'Amasya',
#  'Ankara',
#  'Antalya',
#  'Artvin',
#  'Aydin',
#  'Balikesir',
#  'Batman',
#  'Bayburt',
#  'Bilecik',
#  'Bingol',
#  'Bitlis',
#  'Bolu',
#  'Burdur',
#  'Bursa',
#  'İnegöl',
#  'Canakkale',
#  'Cankiri',
#  'Corum',
#  'Denizli',
#  'Diyarbakir',
#  'Edirne',
#  'Elazig',
#  'Erzincan',
#  'Erzurum',
#  'Eskisehir',
#  'Gaziantep',
#  'Giresun',
#  'Gumushane',
#  'Hakkari',
#  'Iskenderun',
#  'Hatay',
#  'Mersin',
#  'Tarsus',
#  'Isparta',
#  'Istanbul',
#  'Izmir',
#  'Karaman',
#  'Kahramanmaraş',
#  'Kars',
#  'Kastamonu',
#  'Kayseri',
#  'Kirikkale',
#  'Kirklareli',
#  'Luleburgaz',
#  'Kirsehir',
#  'Kocaeli',
#  'Gebze',
#  'Konya',
#  'Kütahya',
#  'Malatya',
#  'Manisa',
#  'Mardin',
#  'Kızıltepe',
#  'Mugla',
#  'Mus',
#  'Nevsehir',
#  'Nigde',
#  'Ordu',
#  'Rize',
#  'Sakarya',
#  'Samsun',
#  'Şanlıurfa',
#  'Siirt',
#  'Sinop',
#  'Sirnak',
#  'Sivas',
#  'Tekirdag',
#  'Çorlu',
#  'Tokat',
#  'Trabzon',
#  'Tunceli',
#  'Usak',
#  'Van',
#  'Yozgat',
#  'Zonguldak',
#  'Bartin',
#  'Karabük',
#  'Ardahan',
#  'Iğdır',
#  'Yalova',
#  'Kilis',
#  'Duzce',
#  'Osmaniye',
#  'Aalborg',
#  'Viborg',
#  'Århus',
#  'Randers',
#  'Vejle',
#  'Odense',
#  'Esbjerg',
#  'Hilleroed',
#  'København',
#  'Soroe',
#  'Tallinn',
#  'Tartu',
#  'Tórshavn',
#  'Mariehamn',
#  'Tampere',
#  'Lahti',
#  'Hämeenlinna',
#  'Kuopio',
#  'Lappeenranta',
#  'Kotka',
#  'Rovaniemi',
#  'Mikkeli',
#  'Jyväskylä',
#  'Joensuu',
#  'Oulu',
#  'Pori',
#  'Turku',
#  'Helsinki',
#  'Espoo',
#  'Vaasa',
#  'Oslo',
#  'Sandvika',
#  'Moss',
#  'Hamar',
#  'Lillehammer',
#  'Drammen',
#  'Tonsberg',
#  'Skien',
#  'Arendal',
#  'Kristiansand',
#  'Stavanger',
#  'Bergen',
#  'Hermannsverk',
#  'Molde',
#  'Trondheim',
#  'Steinkjer',
#  'Svolvaer',
#  'Narvik',
#  'Bodoe',
#  'Tromsø',
#  'Hammerfest',
#  'Vadsoe',
#  'Göteborg',
#  'Vanersborg',
#  'Mariestad',
#  'Borås',
#  'Karlskrona',
#  'Gävle',
#  'Visby',
#  'Halmstad',
#  'Ostersund',
#  'Jönköping',
#  'Kalmar',
#  'Falun',
#  'Malmö',
#  'Helsingborg',
#  'Kristianstad',
#  'Lund',
#  'Växjö',
#  'Lulea',
#  'Jokkmokk',
#  'Örebro',
#  'Linköping',
#  'Norrköping',
#  'Nykoping',
#  'Eskilstuna',
#  'Stockholm',
#  'Huddinge',
#  'Uppsala',
#  'Karlstad',
#  'Umeå',
#  'Harnosand',
#  'Västerås',
#  'Monaco',
#  'Gibraltar',
#  'Saint Peter Port',
#  'Vatican City',
#  'Ceuta',
#  'Melilla',
#  'Reykjavik',
#  'Keflavik',
#  'Hafnarfjordur',
#  'Akureyri',
#  'Dublin',
#  'Cork',
#  'Galway',
#  'Limerick',
#  'San Marino',
#  'Saint Helier',
#  'Valletta',
#  'Victoria',
#  'Douglas',
#  'Chişinău',
#  'Tiraspol',
#  'Bălţi',
#  'Aveiro',
#  'Beja',
#  'Braga',
#  'Braganca',
#  'Castelo Branco',
#  'Coimbra',
#  'Evora',
#  'Faro',
#  'Guarda',
#  'Leiria',
#  'Lisboa',
#  'Amadora',
#  'Barreiro',
#  'Almada',
#  'Portalegre',
#  'Oporto',
#  'Vila Nova de Gaia',
#  'Santarem',
#  'Setúbal',
#  'Viana do Castelo',
#  'Vila Real',
#  'Viseu',
#  'Ponta Delgada',
#  'Funchal',
#  'Longyearbyen',
#  'Newcastle upon Tyne',
#  'Sunderland',
#  'Gateshead',
#  'Middlesbrough',
#  'Manchester',
#  'Wigan',
#  'Stockport',
#  'Bolton',
#  'Salford',
#  'Oldham',
#  'Rochdale',
#  'Warrington',
#  'Blackpool',
#  'Blackburn',
#  'Liverpool',
#  'Birkenhead',
#  'St Helens',
#  'Preston',
#  'Leeds',
#  'Wakefield',
#  'Bradford',
#  'Huddersfield',
#  'Sheffield',
#  'Doncaster',
#  'Rotherham',
#  'York',
#  'Kingston upon Hull',
#  'Nottingham',
#  'Northampton',
#  'Leicester',
#  'Derby',
#  'Lincoln',
#  'Birmingham',
#  'Coventry',
#  'Wolverhampton',
#  'Solihull',
#  'Stoke-on-Trent',
#  'Worcester',
#  'Sutton Coldfield',
#  'Telford',
#  'Cambridge',
#  'Peterborough',
#  'Ipswich',
#  'Chelmsford',
#  'Watford',
#  'Southend-on-Sea',
#  'Basildon',
#  'Colchester',
#  'Norwich',
#  'Luton',
#  ...]

# %% [markdown]
# ### Problem 3. Find the 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %% [markdown]
# ### Problem 4. Find the name and country of a) longest river, b) largest lake and c) airport at highest elevation
